# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/GitHub/Biological-Foundation-Model/Notebooks/scGPT_finetune')
# Out:
# Mounted at /content/drive

# %%
# !git reset --hard origin/main

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/GitHub/Biological-Foundation-Model/Notebooks/scGPT_finetune')

# !pip install -r ./requirements.txt
# !pip install scgpt "flash-attn<1.0.5"
# Out:
# Mounted at /content/drive
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 3)) (2.2.2)
# Collecting torch==2.3.1 (from -r ./requirements.txt (line 6))
#   Downloading torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.18.1 (from -r ./requirements.txt (line 7))
#   Downloading torchvision-0.18.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting torchaudio==2.3.1 (from -r ./requirements.txt (line 8))
#   Downloading torchaudio-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchtext==0.18.0 (from -r ./requirements.txt (line 9))
#   Downloading torchtext-0.18.0-cp312-cp312-manylinux1_x86_64.whl.metadata (7.9 kB)
# Collecting scanpy<2.0,>=1.9.1 (from -r ./requirements.txt (line 12))
#   Downloading scanpy-1.11.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting scvi-tools<1.0,>=0.16.0 (from -r ./requirements.txt (line 13))
#   Downloading scvi_tools-0.20.3-py3-none-any.whl.metadata (9.8 kB)
# Collecting torch_geometric (from -r ./requirements.txt (line 16))
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.4 MB/s eta 0:00:00
# Collecting cell-gears (from -r ./requirements.txt (line 17))
#   Downloading cell_gears-0.1.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting scgpt (from -r ./requirements.txt (line 18))
#   Downloading scgpt-0.2.4-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->-r ./requirements.txt (line 6)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->-r ./requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->-r ./requirements.txt (line 6)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->-r ./requirements.txt (line 6)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->-r ./requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->-r ./requirements.txt (line 6)) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.18.1->-r ./requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torchtext==0.18.0->-r ./requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torchtext==0.18.0->-r ./requirements.txt (line 9)) (2.32.4)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->-r ./requirements.txt (line 6)) (12.6.85)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r ./requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r ./requirements.txt (line 3)) (2025.2)
# Collecting anndata>=0.8 (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading anndata-0.12.2-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (3.14.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (1.5.2)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (8.4.0)
# Requirement already satisfied: numba>=0.57.1 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (0.60.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (25.0)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (0.5.13)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (1.6.1)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (1.16.1)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (0.13.2)
# Collecting session-info2 (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading session_info2-0.2.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (0.14.5)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (0.5.9.post2)
# Requirement already satisfied: chex in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.1.90)
# Collecting docrep>=0.3.2 (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.10.6)
# Requirement already satisfied: jax>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: jaxlib>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.5.3)
# Collecting ml-collections>=0.1.1 (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Collecting mudata>=0.1.2 (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading mudata-0.3.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting numpyro (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading numpyro-0.19.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: openpyxl>=3.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (3.1.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.2.5)
# Collecting pyro-ppl>=1.6.0 (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting pytorch-lightning<1.10.0,>=1.9.0 (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading pytorch_lightning-1.9.5-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (13.9.4)
# Collecting torchmetrics>=0.11.0 (from scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r ./requirements.txt (line 16)) (3.12.15)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r ./requirements.txt (line 16)) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric->-r ./requirements.txt (line 16)) (3.2.3)
# Collecting dcor (from cell-gears->-r ./requirements.txt (line 17))
#   Downloading dcor-0.6-py3-none-any.whl.metadata (6.2 kB)
# Collecting cell-gears (from -r ./requirements.txt (line 17))
#   Downloading cell-gears-0.0.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting datasets<3.0.0,>=2.3.0 (from scgpt->-r ./requirements.txt (line 18))
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting leidenalg>=0.8.10 (from scgpt->-r ./requirements.txt (line 18))
#   Downloading leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting orbax<0.1.8 (from scgpt->-r ./requirements.txt (line 18))
#   Downloading orbax-0.1.7-py3-none-any.whl.metadata (1.9 kB)
# Collecting scib<2.0.0,>=1.0.3 (from scgpt->-r ./requirements.txt (line 18))
#   Downloading scib-1.1.7-1-py3-none-any.whl.metadata (9.8 kB)
# Collecting scikit-misc>=0.1.4 (from scgpt->-r ./requirements.txt (line 18))
#   Downloading scikit_misc-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.8->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.8->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt->-r ./requirements.txt (line 18)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt->-r ./requirements.txt (line 18)) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt->-r ./requirements.txt (line 18)) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt->-r ./requirements.txt (line 18)) (0.70.16)
# Collecting fsspec (from torch==2.3.1->-r ./requirements.txt (line 6))
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt->-r ./requirements.txt (line 18)) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt->-r ./requirements.txt (line 18)) (6.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.2->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.4->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.4->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (3.4.0)
# Collecting igraph<0.12,>=0.10.0 (from leidenalg>=0.8.10->scgpt->-r ./requirements.txt (line 18))
#   Downloading igraph-0.11.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (1.4.9)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections>=0.1.1->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.57.1->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (0.43.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.0->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (2.0.0)
# Collecting cached_property (from orbax<0.1.8->scgpt->-r ./requirements.txt (line 18))
#   Downloading cached_property-2.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt->-r ./requirements.txt (line 18)) (6.5.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt->-r ./requirements.txt (line 18)) (1.1.1)
# Requirement already satisfied: etils in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt->-r ./requirements.txt (line 18)) (1.13.0)
# Requirement already satisfied: tensorstore>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt->-r ./requirements.txt (line 18)) (0.1.76)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt->-r ./requirements.txt (line 18)) (1.6.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.6.0->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting lightning-utilities>=0.6.0.post0 (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13))
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torchtext==0.18.0->-r ./requirements.txt (line 9)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torchtext==0.18.0->-r ./requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torchtext==0.18.0->-r ./requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torchtext==0.18.0->-r ./requirements.txt (line 9)) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (2.19.2)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from scib<2.0.0,>=1.0.3->scgpt->-r ./requirements.txt (line 18)) (3.0.4)
# Collecting deprecated (from scib<2.0.0,>=1.0.3->scgpt->-r ./requirements.txt (line 18))
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.3->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r ./requirements.txt (line 16)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r ./requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r ./requirements.txt (line 16)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r ./requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r ./requirements.txt (line 16)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r ./requirements.txt (line 16)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric->-r ./requirements.txt (line 16)) (1.20.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.11.24)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.1.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.3.1->-r ./requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from numpyro->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.3.1->-r ./requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets<3.0.0,>=2.3.0->scgpt->-r ./requirements.txt (line 18)) (1.1.9)
# Collecting texttable>=1.6.2 (from igraph<0.12,>=0.10.0->leidenalg>=0.8.10->scgpt->-r ./requirements.txt (line 18))
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (0.1.2)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->scib<2.0.0,>=1.0.3->scgpt->-r ./requirements.txt (line 18)) (1.17.3)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (4.13.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (3.20.1)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy<2.0,>=1.9.1->-r ./requirements.txt (line 12))
#   Downloading crc32c-2.7.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->-r ./requirements.txt (line 13)) (3.23.0)
# Downloading torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.1 MB/s eta 0:00:00
# Downloading torchvision-0.18.1-cp312-cp312-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 102.7 MB/s eta 0:00:00
# Downloading torchaudio-2.3.1-cp312-cp312-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 63.5 MB/s eta 0:00:00
# Downloading torchtext-0.18.0-cp312-cp312-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 87.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 30.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.3 MB/s eta 0:00:00
# Downloading scanpy-1.11.4-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 81.4 MB/s eta 0:00:00
# Downloading scvi_tools-0.20.3-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.3/330.3 kB 29.5 MB/s eta 0:00:00
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.8 MB/s eta 0:00:00
# Downloading scgpt-0.2.4-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.7/831.7 kB 50.1 MB/s eta 0:00:00
# Downloading anndata-0.12.2-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 kB 16.0 MB/s eta 0:00:00
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 44.2 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 21.2 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.7 MB/s eta 0:00:00
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.8 MB/s eta 0:00:00
# Downloading mudata-0.3.2-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.0 MB/s eta 0:00:00
# Downloading orbax-0.1.7-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.6 MB/s eta 0:00:00
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 58.6 MB/s eta 0:00:00
# Downloading pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 42.0 MB/s eta 0:00:00
# Downloading scib-1.1.7-1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 9.9 MB/s eta 0:00:00
# Downloading scikit_misc-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.6/183.6 kB 20.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 70.0 MB/s eta 0:00:00
# Downloading dcor-0.6-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 5.7 MB/s eta 0:00:00
# Downloading numpyro-0.19.0-py3-none-any.whl (370 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.9/370.9 kB 36.6 MB/s eta 0:00:00
# Downloading session_info2-0.2.2-py3-none-any.whl (16 kB)
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 6.1 MB/s eta 0:00:00
# Downloading igraph-0.11.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 121.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 30.9 MB/s eta 0:00:00
# Downloading cached_property-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 63.0 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading crc32c-2.7.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 6.1 MB/s eta 0:00:00
# Building wheels for collected packages: cell-gears, docrep
#   Building wheel for cell-gears (setup.py) ... done
#   Created wheel for cell-gears: filename=cell_gears-0.0.2-py3-none-any.whl size=27809 sha256=5c38f2d83439ef814d78e3235fb04ed92cab4315e66b130d16bb825429ef1859
#   Stored in directory: /root/.cache/pip/wheels/c3/7d/33/062df7a4c34312454fa656f964080fe34b4d518fdb851d164f
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19876 sha256=8a83d5d72781bca0dc5d6f36f8982b9f5d60baae8799f19f346416da02cbe8ab
#   Stored in directory: /root/.cache/pip/wheels/d6/19/ee/0a6a1793d91c449563b49ccab57ce52da3e6fab7614836bd8c
# Successfully built cell-gears docrep
# Installing collected packages: texttable, pyro-api, session-info2, scikit-misc, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numcodecs, ml-collections, lightning-utilities, legacy-api-wrap, igraph, fsspec, donfig, docrep, deprecated, crc32c, cached_property, array-api-compat, nvidia-cusolver-cu12, nvidia-cudnn-cu12, leidenalg, dcor, zarr, torch_geometric, torch, torchvision, torchtext, torchmetrics, torchaudio, pyro-ppl, orbax, numpyro, datasets, anndata, scanpy, pytorch-lightning, mudata, scib, cell-gears, scvi-tools, scgpt
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.23.0+cu126
#     Uninstalling torchvision-0.23.0+cu126:
#       Successfully uninstalled torchvision-0.23.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.8.0+cu126
#     Uninstalling torchaudio-2.8.0+cu126:
#       Successfully uninstalled torchaudio-2.8.0+cu126
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.6.1 which is incompatible.
# Successfully installed anndata-0.12.2 array-api-compat-1.12.0 cached_property-2.0.1 cell-gears-0.0.2 crc32c-2.7.1 datasets-2.21.0 dcor-0.6 deprecated-1.2.18 docrep-0.3.2 donfig-0.8.1.post1 fsspec-2024.6.1 igraph-0.11.9 legacy-api-wrap-1.4.1 leidenalg-0.10.2 lightning-utilities-0.15.2 ml-collections-1.1.0 mudata-0.3.2 numcodecs-0.16.3 numpyro-0.19.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 orbax-0.1.7 pyro-api-0.1.2 pyro-ppl-1.9.1 pytorch-lightning-1.9.5 scanpy-1.11.4 scgpt-0.2.4 scib-1.1.7 scikit-misc-0.5.1 scvi-tools-0.20.3 session-info2-0.2.2 texttable-1.7.0 torch-2.3.1 torch_geometric-2.6.1 torchaudio-2.3.1 torchmetrics-1.8.2 torchtext-0.18.0 torchvision-0.18.1 zarr-3.1.3
# Requirement already satisfied: scgpt in /usr/local/lib/python3.12/dist-packages (0.2.4)
# Collecting flash-attn<1.0.5
#   Downloading flash_attn-1.0.4.tar.gz (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 82.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cell-gears<0.0.3 in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.0.2)
# Requirement already satisfied: datasets<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from scgpt) (2.21.0)
# Requirement already satisfied: leidenalg>=0.8.10 in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.10.2)
# Requirement already satisfied: numba>=0.55.1 in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.60.0)
# Requirement already satisfied: orbax<0.1.8 in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.1.7)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.12/dist-packages (from scgpt) (2.2.2)
# Requirement already satisfied: scanpy<2.0.0,>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from scgpt) (1.11.4)
# Requirement already satisfied: scib<2.0.0,>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from scgpt) (1.1.7)
# Requirement already satisfied: scikit-misc>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.5.1)
# Requirement already satisfied: scvi-tools<1.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.20.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from scgpt) (2.3.1)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.18.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from scgpt) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.3 in /usr/local/lib/python3.12/dist-packages (from scgpt) (0.5.9.post2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from flash-attn<1.0.5) (0.8.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from flash-attn<1.0.5) (25.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from cell-gears<0.0.3->scgpt) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cell-gears<0.0.3->scgpt) (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from cell-gears<0.0.3->scgpt) (1.6.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from cell-gears<0.0.3->scgpt) (3.5)
# Requirement already satisfied: dcor in /usr/local/lib/python3.12/dist-packages (from cell-gears<0.0.3->scgpt) (0.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.3.0->scgpt) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (3.12.15)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.3.0->scgpt) (6.0.2)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from leidenalg>=0.8.10->scgpt) (0.11.9)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.55.1->scgpt) (0.43.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (1.4.0)
# Requirement already satisfied: cached_property in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (2.0.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (6.5.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (1.1.1)
# Requirement already satisfied: etils in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (1.13.0)
# Requirement already satisfied: jax>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (0.5.3)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (0.5.3)
# Requirement already satisfied: tensorstore>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (0.1.76)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax<0.1.8->scgpt) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.5->scgpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.5->scgpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.5->scgpt) (2025.2)
# Requirement already satisfied: anndata>=0.8 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.12.2)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (3.14.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.5.2)
# Requirement already satisfied: legacy-api-wrap>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.4.1)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (8.4.0)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.5.13)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (1.16.1)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.13.2)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.2.2)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy<2.0.0,>=1.9.1->scgpt) (0.14.5)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from scib<2.0.0,>=1.0.3->scgpt) (3.0.4)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.12/dist-packages (from scib<2.0.0,>=1.0.3->scgpt) (1.2.18)
# Requirement already satisfied: chex in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.1.90)
# Requirement already satisfied: docrep>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.3.2)
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.10.6)
# Requirement already satisfied: ml-collections>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (1.1.0)
# Requirement already satisfied: mudata>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.3.2)
# Requirement already satisfied: numpyro in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.19.0)
# Requirement already satisfied: openpyxl>=3.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (3.1.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (0.2.5)
# Requirement already satisfied: pyro-ppl>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (1.9.1)
# Requirement already satisfied: pytorch-lightning<1.10.0,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (1.9.5)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (13.9.4)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools<1.0,>=0.16.0->scgpt) (1.8.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->scgpt) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->scgpt) (12.6.85)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.8->scanpy<2.0.0,>=1.9.1->scgpt) (1.12.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.8->scanpy<2.0.0,>=1.9.1->scgpt) (3.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.2->scvi-tools<1.0,>=0.16.0->scgpt) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.3.0->scgpt) (1.20.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets<3.0.0,>=2.3.0->scgpt) (1.1.9)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from igraph<0.12,>=0.10.0->leidenalg>=0.8.10->scgpt) (1.7.0)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.6->orbax<0.1.8->scgpt) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.6->orbax<0.1.8->scgpt) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0.0,>=1.9.1->scgpt) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0.0,>=1.9.1->scgpt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0.0,>=1.9.1->scgpt) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0.0,>=1.9.1->scgpt) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0.0,>=1.9.1->scgpt) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy<2.0.0,>=1.9.1->scgpt) (3.2.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.0->scvi-tools<1.0,>=0.16.0->scgpt) (2.0.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl>=1.6.0->scvi-tools<1.0,>=0.16.0->scgpt) (0.1.2)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools<1.0,>=0.16.0->scgpt) (0.15.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.3.0->scgpt) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.3.0->scgpt) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.3.0->scgpt) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.3.0->scgpt) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->scvi-tools<1.0,>=0.16.0->scgpt) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->scvi-tools<1.0,>=0.16.0->scgpt) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->cell-gears<0.0.3->scgpt) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex->scvi-tools<1.0,>=0.16.0->scgpt) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex->scvi-tools<1.0,>=0.16.0->scgpt) (0.12.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->scib<2.0.0,>=1.0.3->scgpt) (1.17.3)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax->scvi-tools<1.0,>=0.16.0->scgpt) (0.11.24)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax->scvi-tools<1.0,>=0.16.0->scgpt) (0.1.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->scgpt) (3.0.2)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from numpyro->scvi-tools<1.0,>=0.16.0->scgpt) (1.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch>=1.13.0->scgpt) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->scvi-tools<1.0,>=0.16.0->scgpt) (0.1.2)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy<2.0.0,>=1.9.1->scgpt) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy<2.0.0,>=1.9.1->scgpt) (0.16.3)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->scgpt) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->scgpt) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->scgpt) (4.13.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->scgpt) (3.20.1)
# Requirement already satisfied: crc32c>=2.7 in /usr/local/lib/python3.12/dist-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy<2.0.0,>=1.9.1->scgpt) (2.7.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->scvi-tools<1.0,>=0.16.0->scgpt) (3.23.0)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-1.0.4-cp312-cp312-linux_x86_64.whl size=72831009 sha256=dbbe28ca9392e41a6c453e2d74744c78a404bc0071e2f8f8123474f4c72589c0
#   Stored in directory: /root/.cache/pip/wheels/e6/d9/e4/0b3fc5da539a482a48b9b041e20a07fec0964ba6b4e7148e5e
# Successfully built flash-attn
# Installing collected packages: flash-attn
# Successfully installed flash-attn-1.0.4

# %% [markdown]
# ## Load pretrained/finetuned models

# %%
import json
import os
import sys
import time
import copy
from pathlib import Path
from typing import Iterable, List, Tuple, Dict, Union, Optional
import warnings

import torch
import numpy as np
import matplotlib
from torch import nn
from torch.nn import functional as F
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)
from torch_geometric.loader import DataLoader
from gears import PertData, GEARS
from gears.inference import compute_metrics, deeper_analysis, non_dropout_analysis
from gears.utils import create_cell_graph_dataset_for_prediction

sys.path.insert(0, "../")

import scgpt as scg
from scgpt.model import TransformerGenerator
from scgpt.loss import (
    masked_mse_loss,
    criterion_neg_log_bernoulli,
    masked_relative_error,
)
from scgpt.tokenizer import tokenize_batch, pad_batch, tokenize_and_pad_batch
from scgpt.tokenizer.gene_tokenizer import GeneVocab
from scgpt.utils import set_seed, map_raw_id_to_vocab_id, compute_perturbation_metrics

matplotlib.rcParams["savefig.transparent"] = False
warnings.filterwarnings("ignore")

set_seed(42)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.12/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %%
# settings for data prcocessing
pad_token = "<pad>"
special_tokens = [pad_token, "<cls>", "<eoc>"]
pad_value = 0  # for padding values
pert_pad_id = 0
include_zero_gene = "all"
max_seq_len = 1536

# settings for training
MLM = True  # whether to use masked language modeling, currently it is always on.
CLS = False  # celltype classification objective
CCE = False  # Contrastive cell embedding objective
MVC = False  # Masked value prediction for cell embedding
ECS = False  # Elastic cell similarity objective
amp = True
load_model = "./save/scGPT_human"
load_param_prefixs = [
    "encoder",
    "value_encoder",
    "transformer_encoder",
]

# settings for optimizer
lr = 1e-4  # or 1e-4
batch_size = 64
eval_batch_size = 64
epochs = 15
schedule_interval = 1
early_stop = 10

# settings for the model
embsize = 512  # embedding dimension
d_hid = 512  # dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 12  # number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 8  # number of heads in nn.MultiheadAttention
n_layers_cls = 3
dropout = 0  # dropout probability
use_fast_transformer = True  # whether to use fast transformer

# logging
log_interval = 100

# dataset and evaluation choices
data_name = "adamson"
split = "simulation"
if data_name == "norman":
    perts_to_plot = ["SAMD1+ZBTB1"]
elif data_name == "adamson":
    perts_to_plot = ["KCTD16+ctrl"]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
save_dir = Path(f"./save/dev_perturb_{data_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"saving to {save_dir}")

logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")
# log running date and current git commit
logger.info(f"Running on {time.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# saving to save/dev_perturb_adamson-Sep22-00-13
# scGPT - INFO - Running on 2025-09-22 00:13:34

# %%
pert_data = PertData("./data")
pert_data.load(data_name=data_name)
pert_data.prepare_split(split=split, seed=1)
pert_data.get_dataloader(batch_size=batch_size, test_batch_size=eval_batch_size)
# Out:
# Found local copy...
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:22
# Done!
# Creating dataloaders....
# Done!

# %%
if load_model is not None:
    model_dir = Path("./save/scGPT_human")
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    pert_data.adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in pert_data.adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(pert_data.adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    genes = pert_data.adata.var["gene_name"].tolist()

    # model
    with open(model_config_file, "r") as f:
        model_configs = json.load(f)
    logger.info(
        f"Resume model from {model_file}, the model args will override the "
        f"config {model_config_file}."
    )
    embsize = model_configs["embsize"]
    nhead = model_configs["nheads"]
    d_hid = model_configs["d_hid"]
    nlayers = model_configs["nlayers"]
    n_layers_cls = model_configs["n_layers_cls"]
else:
    genes = pert_data.adata.var["gene_name"].tolist()
    vocab = Vocab(
        VocabPybind(genes + special_tokens, None)
    )  # bidirectional lookup [gene <-> int]
vocab.set_default_index(vocab["<pad>"])
gene_ids = np.array(
    [vocab[gene] if gene in vocab else vocab["<pad>"] for gene in genes], dtype=int
)
n_genes = len(genes)
# Out:
# scGPT - INFO - match 4399/5060 genes in vocabulary of size 60697.
# scGPT - INFO - Resume model from save/scGPT_human/best_model.pt, the model args will override the config save/scGPT_human/args.json.

# %%
ntokens = len(vocab)  # size of vocabulary
model_pretrain = TransformerGenerator(
    ntokens,
    embsize,
    nhead,
    d_hid,
    nlayers,
    nlayers_cls=n_layers_cls,
    n_cls=1,
    vocab=vocab,
    dropout=dropout,
    pad_token=pad_token,
    pad_value=pad_value,
    pert_pad_id=pert_pad_id,
    use_fast_transformer=use_fast_transformer,
)
if load_param_prefixs is not None and load_model is not None:
    # only load params that start with the prefix
    model_dict = model_pretrain.state_dict()
    pretrained_dict = torch.load(model_file)
    pretrained_dict = {
        k: v
        for k, v in pretrained_dict.items()
        if any([k.startswith(prefix) for prefix in load_param_prefixs])
    }
    for k, v in pretrained_dict.items():
        logger.info(f"Loading params {k} with shape {v.shape}")
    model_dict.update(pretrained_dict)
    model_pretrain.load_state_dict(model_dict)
elif load_model is not None:
    try:
        model_pretrain.load_state_dict(torch.load(model_file))
        logger.info(f"Loading all model params from {model_file}")
    except:
        # only load params that are in the model and match the size
        model_dict = model_pretrain.state_dict()
        pretrained_dict = torch.load(model_file)
        pretrained_dict = {
            k: v
            for k, v in pretrained_dict.items()
            if k in model_dict and v.shape == model_dict[k].shape
        }
        for k, v in pretrained_dict.items():
            logger.info(f"Loading params {k} with shape {v.shape}")
        model_dict.update(pretrained_dict)
        model_pretrain.load_state_dict(model_dict)
model_pretrain.to(device)
# Out:
# scGPT - INFO - Loading params encoder.embedding.weight with shape torch.Size([60697, 512])
# scGPT - INFO - Loading params encoder.enc_norm.weight with shape torch.Size([512])
# scGPT - INFO - Loading params encoder.enc_norm.bias with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.linear1.weight with shape torch.Size([512, 1])
# scGPT - INFO - Loading params value_encoder.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params value_encoder.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.norm.weight with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.norm.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm2.bias with shape torch.Size([512])
# TransformerGenerator(
#   (encoder): GeneEncoder(
#     (embedding): Embedding(60697, 512, padding_idx=60694)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (value_encoder): ContinuousValueEncoder(
#     (dropout): Dropout(p=0, inplace=False)
#     (linear1): Linear(in_features=1, out_features=512, bias=True)
#     (activation): ReLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (pert_encoder): Embedding(3, 512, padding_idx=0)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0, inplace=False)
#         (dropout2): Dropout(p=0, inplace=False)
#       )
#     )
#   )
#   (decoder): AffineExprDecoder(
#     (coeff_decoder): ExprDecoder(
#       (fc): Sequential(
#         (0): Linear(in_features=512, out_features=512, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Linear(in_features=512, out_features=512, bias=True)
#         (3): LeakyReLU(negative_slope=0.01)
#         (4): Linear(in_features=512, out_features=1, bias=True)
#       )
#     )
#     (bias_decoder): ExprDecoder(
#       (fc): Sequential(
#         (0): Linear(in_features=512, out_features=512, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Linear(in_features=512, out_features=512, bias=True)
#         (3): LeakyReLU(negative_slope=0.01)
#         (4): Linear(in_features=512, out_features=1, bias=True)
#       )
#     )
#   )
#   (cls_decoder): ClsDecoder(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): ReLU()
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %%
if load_model is not None:
    model_dir = Path("./save/scGPT_human")
    model_config_file = model_dir / "args.json"
    vocab_file = model_dir / "vocab.json"
    model_dir = Path("./save/scGPT_human_finetuned_adamson")
    model_file = model_dir / "best_model.pt"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    pert_data.adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in pert_data.adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(pert_data.adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    genes = pert_data.adata.var["gene_name"].tolist()

    # model
    with open(model_config_file, "r") as f:
        model_configs = json.load(f)
    logger.info(
        f"Resume model from {model_file}, the model args will override the "
        f"config {model_config_file}."
    )
    embsize = model_configs["embsize"]
    nhead = model_configs["nheads"]
    d_hid = model_configs["d_hid"]
    nlayers = model_configs["nlayers"]
    n_layers_cls = model_configs["n_layers_cls"]
else:
    genes = pert_data.adata.var["gene_name"].tolist()
    vocab = Vocab(
        VocabPybind(genes + special_tokens, None)
    )  # bidirectional lookup [gene <-> int]
vocab.set_default_index(vocab["<pad>"])
gene_ids = np.array(
    [vocab[gene] if gene in vocab else vocab["<pad>"] for gene in genes], dtype=int
)
n_genes = len(genes)
# Out:
# scGPT - INFO - match 4399/5060 genes in vocabulary of size 60697.
# scGPT - INFO - Resume model from save/scGPT_human_finetuned_adamson/best_model.pt, the model args will override the config save/scGPT_human/args.json.

# %%
ntokens = len(vocab)  # size of vocabulary
model_finetune = TransformerGenerator(
    ntokens,
    embsize,
    nhead,
    d_hid,
    nlayers,
    nlayers_cls=n_layers_cls,
    n_cls=1,
    vocab=vocab,
    dropout=dropout,
    pad_token=pad_token,
    pad_value=pad_value,
    pert_pad_id=pert_pad_id,
    use_fast_transformer=use_fast_transformer,
)
if load_param_prefixs is not None and load_model is not None:
    # only load params that start with the prefix
    model_dict = model_finetune.state_dict()
    pretrained_dict = torch.load(model_file)
    pretrained_dict = {
        k: v
        for k, v in pretrained_dict.items()
        if any([k.startswith(prefix) for prefix in load_param_prefixs])
    }
    for k, v in pretrained_dict.items():
        logger.info(f"Loading params {k} with shape {v.shape}")
    model_dict.update(pretrained_dict)
    model_finetune.load_state_dict(model_dict)
elif load_model is not None:
    try:
        model_finetune.load_state_dict(torch.load(model_file))
        logger.info(f"Loading all model params from {model_file}")
    except:
        # only load params that are in the model and match the size
        model_dict = model_finetune.state_dict()
        pretrained_dict = torch.load(model_file)
        pretrained_dict = {
            k: v
            for k, v in pretrained_dict.items()
            if k in model_dict and v.shape == model_dict[k].shape
        }
        for k, v in pretrained_dict.items():
            logger.info(f"Loading params {k} with shape {v.shape}")
        model_dict.update(pretrained_dict)
        model_finetune.load_state_dict(model_dict)
model_finetune.to(device)
# Out:
# scGPT - INFO - Loading params encoder.embedding.weight with shape torch.Size([60697, 512])
# scGPT - INFO - Loading params encoder.enc_norm.weight with shape torch.Size([512])
# scGPT - INFO - Loading params encoder.enc_norm.bias with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.linear1.weight with shape torch.Size([512, 1])
# scGPT - INFO - Loading params value_encoder.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params value_encoder.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.norm.weight with shape torch.Size([512])
# scGPT - INFO - Loading params value_encoder.norm.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.0.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.1.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.2.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.3.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.4.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.5.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.6.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.7.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.8.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.9.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.10.norm2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.Wqkv.weight with shape torch.Size([1536, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.Wqkv.bias with shape torch.Size([1536])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.out_proj.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.self_attn.out_proj.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear1.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm1.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm1.bias with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm2.weight with shape torch.Size([512])
# scGPT - INFO - Loading params transformer_encoder.layers.11.norm2.bias with shape torch.Size([512])
# TransformerGenerator(
#   (encoder): GeneEncoder(
#     (embedding): Embedding(60697, 512, padding_idx=60694)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (value_encoder): ContinuousValueEncoder(
#     (dropout): Dropout(p=0, inplace=False)
#     (linear1): Linear(in_features=1, out_features=512, bias=True)
#     (activation): ReLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (pert_encoder): Embedding(3, 512, padding_idx=0)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0, inplace=False)
#         (dropout2): Dropout(p=0, inplace=False)
#       )
#     )
#   )
#   (decoder): AffineExprDecoder(
#     (coeff_decoder): ExprDecoder(
#       (fc): Sequential(
#         (0): Linear(in_features=512, out_features=512, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Linear(in_features=512, out_features=512, bias=True)
#         (3): LeakyReLU(negative_slope=0.01)
#         (4): Linear(in_features=512, out_features=1, bias=True)
#       )
#     )
#     (bias_decoder): ExprDecoder(
#       (fc): Sequential(
#         (0): Linear(in_features=512, out_features=512, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Linear(in_features=512, out_features=512, bias=True)
#         (3): LeakyReLU(negative_slope=0.01)
#         (4): Linear(in_features=512, out_features=1, bias=True)
#       )
#     )
#   )
#   (cls_decoder): ClsDecoder(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): ReLU()
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Extract perturbation embedding

# %%
import numpy as np
import torch
from typing import List, Dict, Optional

def generate_perturbation_embeddings(
    model: "TransformerGenerator",
    pert_genes: List[str],
    ctrl_adata,
    gene_list: List[str],
    pool_size: Optional[int] = None,
    gene_ids: Dict[str, int] = None,  # mapping used by map_raw_id_to_vocab_id
    amp: bool = True,
) -> Dict[str, np.ndarray]:
    """
    Generate embeddings that capture the "essence" of each perturbation type.
    """
    model.eval()
    device = next(model.parameters()).device
    use_amp = bool(amp and device.type == "cuda")

    if pool_size is None:
        pool_size = len(ctrl_adata.obs)

    # gene name -> index in gene_list
    gene_name_to_idx = {g: i for i, g in enumerate(gene_list)}

    perturbation_embeddings: Dict[str, np.ndarray] = {}

    # helper: get a 1D float32 numpy array for a control cell row
    def _row_to_np(idx: int) -> np.ndarray:
        row = ctrl_adata.X[idx]
        if hasattr(row, "toarray"):  # sparse
            return row.toarray().ravel().astype(np.float32)
        return np.asarray(row, dtype=np.float32).ravel()

    # helper: ensure mapped ids are a LongTensor on device
    def _to_long_dev(x):
        if isinstance(x, torch.Tensor):
            return x.to(device=device, dtype=torch.long)
        return torch.as_tensor(x, dtype=torch.long, device=device)

    with torch.no_grad():
        n_genes = len(gene_list)
        # raw gene indices [0..n_genes-1] on device
        input_gene_ids_raw = torch.arange(n_genes, device=device, dtype=torch.long)

        # map to vocab ids (whatever your function returns)
        mapped_input_gene_ids = map_raw_id_to_vocab_id(input_gene_ids_raw, gene_ids)
        mapped_input_gene_ids = _to_long_dev(mapped_input_gene_ids).unsqueeze(0)  # [1, n_genes]

        for pert_gene in pert_genes:
            print(f"Generating embedding for perturbation: {pert_gene}")

            if pert_gene not in gene_name_to_idx:
                print(f"Warning: {pert_gene} not in gene list, skipping…")
                continue

            pert_gene_idx = gene_name_to_idx[pert_gene]
            all_embeddings = []

            # sample control indices
            num_ctrl = len(ctrl_adata.obs)
            sampled = np.random.choice(num_ctrl, size=min(pool_size, num_ctrl), replace=False)

            for idx in sampled:
                # values: [n_genes] -> [1, n_genes] float32 on device
                vals_np = _row_to_np(idx)
                input_values = torch.from_numpy(vals_np).to(device=device, dtype=torch.float32).unsqueeze(0)

                # pert flags: [1, n_genes] long on device (0 everywhere, 1 at target gene)
                input_pert_flags = torch.zeros(n_genes, dtype=torch.long, device=device).unsqueeze(0)
                input_pert_flags[0, pert_gene_idx] = 1

                # padding mask: no padding -> all False, shape [1, n_genes], bool on device
                src_key_padding_mask = torch.zeros_like(input_values, dtype=torch.bool, device=device)

                # forward
                if use_amp:
                    with torch.cuda.amp.autocast():
                        tr_out = model._encode(
                            mapped_input_gene_ids,    # [1, n_genes] long
                            input_values,             # [1, n_genes] float
                            input_pert_flags,         # [1, n_genes] long
                            src_key_padding_mask,     # [1, n_genes] bool
                        )
                        cell_emb = model._get_cell_emb_from_layer(tr_out, input_values)
                else:
                    tr_out = model._encode(
                        mapped_input_gene_ids,
                        input_values,
                        input_pert_flags,
                        src_key_padding_mask,
                    )
                    cell_emb = model._get_cell_emb_from_layer(tr_out, input_values)

                all_embeddings.append(cell_emb.detach().to(torch.float32).cpu().numpy())

            if all_embeddings:
                avg = np.mean(all_embeddings, axis=0)
                perturbation_embeddings[pert_gene] = avg
                print(f"Generated embedding for {pert_gene}: shape {avg.shape}")
            else:
                print(f"No embeddings generated for {pert_gene}")
    return perturbation_embeddings

# %%
with open("pert_gene_list.json") as f:
    pert_gene_list = json.load(f)

# %%
adata = pert_data.adata
ctrl_adata = adata[adata.obs["condition"] == "ctrl"]
gene_list = pert_data.gene_names.values.tolist()

# Define perturbation genes
perturbation_genes = pert_gene_list  # Replace with actual gene names

# Generate perturbation embeddings
pert_embeddings_pretrain = generate_perturbation_embeddings(
    model=model_pretrain,
    pert_genes=perturbation_genes,
    ctrl_adata=ctrl_adata,
    gene_list=gene_list,
    pool_size=100,  # Use 100 control cells for averaging
    gene_ids=gene_ids,
    amp=amp
)

# Print results
print("\nPerturbation Embeddings Generated:")
for gene, embedding in pert_embeddings_pretrain.items():
    print(f"{gene}: {embedding.shape}")

# %%
pert_embeddings_finetune = generate_perturbation_embeddings(
    model=model_finetune,
    pert_genes=perturbation_genes,
    ctrl_adata=ctrl_adata,
    gene_list=gene_list,
    pool_size=100,  # Use 100 control cells for averaging
    gene_ids=gene_ids,
    amp=amp
)

# Print results
print("\nPerturbation Embeddings Generated:")
for gene, embedding in pert_embeddings_finetune.items():
    print(f"{gene}: {embedding.shape}")
# Out:
# Generating embedding for perturbation: UBL5
# Warning: UBL5 not in gene list, skipping…
# Generating embedding for perturbation: TIMM9
# Warning: TIMM9 not in gene list, skipping…
# Generating embedding for perturbation: SMG5
# Warning: SMG5 not in gene list, skipping…
# Generating embedding for perturbation: MED9
# Warning: MED9 not in gene list, skipping…
# Generating embedding for perturbation: MED1
# Warning: MED1 not in gene list, skipping…
# Generating embedding for perturbation: HNRNPH1
# Generated embedding for HNRNPH1: shape (1, 512)
# Generating embedding for perturbation: RPL10A
# Warning: RPL10A not in gene list, skipping…
# Generating embedding for perturbation: LIN54
# Warning: LIN54 not in gene list, skipping…
# Generating embedding for perturbation: EIF1AX
# Warning: EIF1AX not in gene list, skipping…
# Generating embedding for perturbation: NUP98
# Warning: NUP98 not in gene list, skipping…
# Generating embedding for perturbation: N6AMT1
# Warning: N6AMT1 not in gene list, skipping…
# Generating embedding for perturbation: RPS20
# Warning: RPS20 not in gene list, skipping…
# Generating embedding for perturbation: RIOK2
# Generated embedding for RIOK2: shape (1, 512)
# Generating embedding for perturbation: POP7
# Warning: POP7 not in gene list, skipping…
# Generating embedding for perturbation: EIF3E
# Generated embedding for EIF3E: shape (1, 512)
# Generating embedding for perturbation: MRPS14
# Warning: MRPS14 not in gene list, skipping…
# Generating embedding for perturbation: ctrl
# Warning: ctrl not in gene list, skipping…
# Generating embedding for perturbation: MRPL2
# Warning: MRPL2 not in gene list, skipping…
# Generating embedding for perturbation: MED10
# Warning: MED10 not in gene list, skipping…
# Generating embedding for perturbation: TRA2B
# Warning: TRA2B not in gene list, skipping…
# Generating embedding for perturbation: PSMC4
# Warning: PSMC4 not in gene list, skipping…
# Generating embedding for perturbation: CDAN1
# Warning: CDAN1 not in gene list, skipping…
# Generating embedding for perturbation: PPP4C
# Warning: PPP4C not in gene list, skipping…
# Generating embedding for perturbation: TUBGCP2
# Warning: TUBGCP2 not in gene list, skipping…
# Generating embedding for perturbation: EIF3M
# Warning: EIF3M not in gene list, skipping…
# Generating embedding for perturbation: RPL5
# Warning: RPL5 not in gene list, skipping…
# Generating embedding for perturbation: TICRR
# Warning: TICRR not in gene list, skipping…
# Generating embedding for perturbation: RPL13
# Warning: RPL13 not in gene list, skipping…
# Generating embedding for perturbation: CNOT3
# Warning: CNOT3 not in gene list, skipping…
# Generating embedding for perturbation: WDR36
# Generated embedding for WDR36: shape (1, 512)
# Generating embedding for perturbation: RPL31
# Warning: RPL31 not in gene list, skipping…
# Generating embedding for perturbation: SNAPC3
# Warning: SNAPC3 not in gene list, skipping…
# Generating embedding for perturbation: MED12
# Warning: MED12 not in gene list, skipping…
# Generating embedding for perturbation: NBAS
# Generated embedding for NBAS: shape (1, 512)
# Generating embedding for perturbation: CKAP5
# Generated embedding for CKAP5: shape (1, 512)
# Generating embedding for perturbation: ELP5
# Warning: ELP5 not in gene list, skipping…
# Generating embedding for perturbation: RPS6
# Generated embedding for RPS6: shape (1, 512)
# Generating embedding for perturbation: SEC13
# Warning: SEC13 not in gene list, skipping…
# Generating embedding for perturbation: EIF4E
# Warning: EIF4E not in gene list, skipping…
# Generating embedding for perturbation: EEF1G
# Warning: EEF1G not in gene list, skipping…
# Generating embedding for perturbation: LSG1
# Warning: LSG1 not in gene list, skipping…
# Generating embedding for perturbation: FBXO5
# Generated embedding for FBXO5: shape (1, 512)
# Generating embedding for perturbation: MTOR
# Warning: MTOR not in gene list, skipping…
# Generating embedding for perturbation: SFSWAP
# Warning: SFSWAP not in gene list, skipping…
# Generating embedding for perturbation: SUPT5H
# Warning: SUPT5H not in gene list, skipping…
# Generating embedding for perturbation: EIF4G1
# Generated embedding for EIF4G1: shape (1, 512)
# Generating embedding for perturbation: RPA1
# Warning: RPA1 not in gene list, skipping…
# Generating embedding for perturbation: TRRAP
# Warning: TRRAP not in gene list, skipping…
# Generating embedding for perturbation: PRPF40A
# Warning: PRPF40A not in gene list, skipping…
# Generating embedding for perturbation: HSPA9
# Generated embedding for HSPA9: shape (1, 512)
# Generating embedding for perturbation: SLU7
# Generated embedding for SLU7: shape (1, 512)
# Generating embedding for perturbation: DDX46
# Generated embedding for DDX46: shape (1, 512)
# Generating embedding for perturbation: NOP16
# Generated embedding for NOP16: shape (1, 512)
# Generating embedding for perturbation: PMPCA
# Warning: PMPCA not in gene list, skipping…
# Generating embedding for perturbation: HARS2
# Warning: HARS2 not in gene list, skipping…
# Generating embedding for perturbation: POLA1
# Generated embedding for POLA1: shape (1, 512)
# Generating embedding for perturbation: ERH
# Warning: ERH not in gene list, skipping…
# Generating embedding for perturbation: MRPS7
# Warning: MRPS7 not in gene list, skipping…
# Generating embedding for perturbation: CENPJ
# Warning: CENPJ not in gene list, skipping…
# Generating embedding for perturbation: MRPS28
# Warning: MRPS28 not in gene list, skipping…
# Generating embedding for perturbation: SLC7A5
# Generated embedding for SLC7A5: shape (1, 512)
# Generating embedding for perturbation: RPS27
# Generated embedding for RPS27: shape (1, 512)
# Generating embedding for perturbation: SUPT6H
# Warning: SUPT6H not in gene list, skipping…
# Generating embedding for perturbation: U2SURP
# Warning: U2SURP not in gene list, skipping…
# Generating embedding for perturbation: GFER
# Warning: GFER not in gene list, skipping…
# Generating embedding for perturbation: FAM136A
# Warning: FAM136A not in gene list, skipping…
# Generating embedding for perturbation: C1QBP
# Warning: C1QBP not in gene list, skipping…
# Generating embedding for perturbation: ZMAT2
# Warning: ZMAT2 not in gene list, skipping…
# Generating embedding for perturbation: RSL24D1
# Generated embedding for RSL24D1: shape (1, 512)
# Generating embedding for perturbation: PMPCB
# Warning: PMPCB not in gene list, skipping…
# Generating embedding for perturbation: RPS13
# Warning: RPS13 not in gene list, skipping…
# Generating embedding for perturbation: SUGP1
# Warning: SUGP1 not in gene list, skipping…
# Generating embedding for perturbation: BTF3
# Warning: BTF3 not in gene list, skipping…
# Generating embedding for perturbation: PGD
# Warning: PGD not in gene list, skipping…
# Generating embedding for perturbation: SNRNP200
# Warning: SNRNP200 not in gene list, skipping…
# Generating embedding for perturbation: BCAS2
# Warning: BCAS2 not in gene list, skipping…
# Generating embedding for perturbation: RAD51
# Warning: RAD51 not in gene list, skipping…
# Generating embedding for perturbation: SLC39A9
# Warning: SLC39A9 not in gene list, skipping…
# Generating embedding for perturbation: NUDC
# Warning: NUDC not in gene list, skipping…
# Generating embedding for perturbation: PCF11
# Generated embedding for PCF11: shape (1, 512)
# Generating embedding for perturbation: SAE1
# Warning: SAE1 not in gene list, skipping…
# Generating embedding for perturbation: SERBP1
# Warning: SERBP1 not in gene list, skipping…
# Generating embedding for perturbation: ABCB7
# Warning: ABCB7 not in gene list, skipping…
# Generating embedding for perturbation: PSMA3
# Warning: PSMA3 not in gene list, skipping…
# Generating embedding for perturbation: TFIP11
# Warning: TFIP11 not in gene list, skipping…
# Generating embedding for perturbation: RPS26
# Generated embedding for RPS26: shape (1, 512)
# Generating embedding for perturbation: MAK16
# Warning: MAK16 not in gene list, skipping…
# Generating embedding for perturbation: TIMM23B
# Warning: TIMM23B not in gene list, skipping…
# Generating embedding for perturbation: GRPEL1
# Warning: GRPEL1 not in gene list, skipping…
# Generating embedding for perturbation: EIF3A
# Generated embedding for EIF3A: shape (1, 512)
# Generating embedding for perturbation: METAP2
# Warning: METAP2 not in gene list, skipping…
# Generating embedding for perturbation: ZCCHC9
# Warning: ZCCHC9 not in gene list, skipping…
# Generating embedding for perturbation: LAMTOR4
# Warning: LAMTOR4 not in gene list, skipping…
# Generating embedding for perturbation: RPL37
# Generated embedding for RPL37: shape (1, 512)
# Generating embedding for perturbation: RSL1D1
# Warning: RSL1D1 not in gene list, skipping…
# Generating embedding for perturbation: ACTL6A
# Warning: ACTL6A not in gene list, skipping…
# Generating embedding for perturbation: PHF5A
# Warning: PHF5A not in gene list, skipping…
# Generating embedding for perturbation: ZNHIT6
# Generated embedding for ZNHIT6: shape (1, 512)
# Generating embedding for perturbation: NUF2
# Generated embedding for NUF2: shape (1, 512)
# Generating embedding for perturbation: NIP7
# Warning: NIP7 not in gene list, skipping…
# Generating embedding for perturbation: BUB3
# Generated embedding for BUB3: shape (1, 512)
# Generating embedding for perturbation: CDK9
# Warning: CDK9 not in gene list, skipping…
# Generating embedding for perturbation: SAMM50
# Generated embedding for SAMM50: shape (1, 512)
# Generating embedding for perturbation: SRBD1
# Warning: SRBD1 not in gene list, skipping…
# Generating embedding for perturbation: MFAP1
# Generated embedding for MFAP1: shape (1, 512)
# Generating embedding for perturbation: ALG2
# Warning: ALG2 not in gene list, skipping…
# Generating embedding for perturbation: PSMC2
# Generated embedding for PSMC2: shape (1, 512)
# Generating embedding for perturbation: CSE1L
# Warning: CSE1L not in gene list, skipping…
# Generating embedding for perturbation: RPS24
# Generated embedding for RPS24: shape (1, 512)
# Generating embedding for perturbation: RPS19
# Warning: RPS19 not in gene list, skipping…
# Generating embedding for perturbation: ARGLU1
# Generated embedding for ARGLU1: shape (1, 512)
# Generating embedding for perturbation: GTF2H4
# Warning: GTF2H4 not in gene list, skipping…
# Generating embedding for perturbation: GTF2E2
# Warning: GTF2E2 not in gene list, skipping…
# Generating embedding for perturbation: NUMA1
# Warning: NUMA1 not in gene list, skipping…
# Generating embedding for perturbation: DYNLRB1
# Warning: DYNLRB1 not in gene list, skipping…
# Generating embedding for perturbation: KRR1
# Warning: KRR1 not in gene list, skipping…
# Generating embedding for perturbation: THOC6
# Warning: THOC6 not in gene list, skipping…
# Generating embedding for perturbation: INTS8
# Warning: INTS8 not in gene list, skipping…
# Generating embedding for perturbation: DYNC1I2
# Warning: DYNC1I2 not in gene list, skipping…
# Generating embedding for perturbation: HSPA5
# Generated embedding for HSPA5: shape (1, 512)
# Generating embedding for perturbation: MCM4
# Generated embedding for MCM4: shape (1, 512)
# Generating embedding for perturbation: PSMD11
# Generated embedding for PSMD11: shape (1, 512)
# Generating embedding for perturbation: SRP72
# Generated embedding for SRP72: shape (1, 512)
# Generating embedding for perturbation: MRPL55
# Warning: MRPL55 not in gene list, skipping…
# Generating embedding for perturbation: AHCY
# Warning: AHCY not in gene list, skipping…
# Generating embedding for perturbation: CRNKL1
# Warning: CRNKL1 not in gene list, skipping…
# Generating embedding for perturbation: NELFCD
# Warning: NELFCD not in gene list, skipping…
# Generating embedding for perturbation: PSMB7
# Warning: PSMB7 not in gene list, skipping…
# Generating embedding for perturbation: SRSF11
# Warning: SRSF11 not in gene list, skipping…
# Generating embedding for perturbation: TSR2
# Warning: TSR2 not in gene list, skipping…
# Generating embedding for perturbation: DNMT1
# Warning: DNMT1 not in gene list, skipping…
# Generating embedding for perturbation: PDCD11
# Warning: PDCD11 not in gene list, skipping…
# Generating embedding for perturbation: NCBP2
# Warning: NCBP2 not in gene list, skipping…
# Generating embedding for perturbation: C7orf26
# Warning: C7orf26 not in gene list, skipping…
# Generating embedding for perturbation: BUD13
# Warning: BUD13 not in gene list, skipping…
# Generating embedding for perturbation: DYNLL1
# Warning: DYNLL1 not in gene list, skipping…
# Generating embedding for perturbation: SNRPD3
# Warning: SNRPD3 not in gene list, skipping…
# Generating embedding for perturbation: COG2
# Warning: COG2 not in gene list, skipping…
# Generating embedding for perturbation: SFPQ
# Generated embedding for SFPQ: shape (1, 512)
# Generating embedding for perturbation: SDE2
# Generated embedding for SDE2: shape (1, 512)
# Generating embedding for perturbation: MRPL18
# Warning: MRPL18 not in gene list, skipping…
# Generating embedding for perturbation: RPL34
# Generated embedding for RPL34: shape (1, 512)
# Generating embedding for perturbation: RPS3
# Warning: RPS3 not in gene list, skipping…
# Generating embedding for perturbation: NAA15
# Warning: NAA15 not in gene list, skipping…
# Generating embedding for perturbation: DONSON
# Warning: DONSON not in gene list, skipping…
# Generating embedding for perturbation: KANSL3
# Warning: KANSL3 not in gene list, skipping…
# Generating embedding for perturbation: DNM1L
# Warning: DNM1L not in gene list, skipping…
# Generating embedding for perturbation: WDR33
# Warning: WDR33 not in gene list, skipping…
# Generating embedding for perturbation: ANAPC4
# Warning: ANAPC4 not in gene list, skipping…
# Generating embedding for perturbation: DSN1
# Warning: DSN1 not in gene list, skipping…
# Generating embedding for perturbation: RPLP2
# Warning: RPLP2 not in gene list, skipping…
# Generating embedding for perturbation: RARS2
# Warning: RARS2 not in gene list, skipping…
# Generating embedding for perturbation: COPS3
# Warning: COPS3 not in gene list, skipping…
# Generating embedding for perturbation: PPIE
# Warning: PPIE not in gene list, skipping…
# Generating embedding for perturbation: UQCRQ
# Warning: UQCRQ not in gene list, skipping…
# Generating embedding for perturbation: RPF1
# Warning: RPF1 not in gene list, skipping…
# Generating embedding for perturbation: LSM5
# Warning: LSM5 not in gene list, skipping…
# Generating embedding for perturbation: ZBTB17
# Warning: ZBTB17 not in gene list, skipping…
# Generating embedding for perturbation: DPH2
# Warning: DPH2 not in gene list, skipping…
# Generating embedding for perturbation: POLR2G
# Warning: POLR2G not in gene list, skipping…
# Generating embedding for perturbation: RPS29
# Generated embedding for RPS29: shape (1, 512)
# Generating embedding for perturbation: TCOF1
# Warning: TCOF1 not in gene list, skipping…
# Generating embedding for perturbation: USP39
# Warning: USP39 not in gene list, skipping…
# Generating embedding for perturbation: TAF10
# Warning: TAF10 not in gene list, skipping…
# Generating embedding for perturbation: GARS
# Generated embedding for GARS: shape (1, 512)
# Generating embedding for perturbation: CNOT1
# Warning: CNOT1 not in gene list, skipping…
# Generating embedding for perturbation: CHD4
# Generated embedding for CHD4: shape (1, 512)
# Generating embedding for perturbation: XPO1
# Generated embedding for XPO1: shape (1, 512)
# Generating embedding for perturbation: SART1
# Warning: SART1 not in gene list, skipping…
# Generating embedding for perturbation: RPS10
# Generated embedding for RPS10: shape (1, 512)
# Generating embedding for perturbation: MRPS23
# Warning: MRPS23 not in gene list, skipping…
# Generating embedding for perturbation: NUP54
# Warning: NUP54 not in gene list, skipping…
# Generating embedding for perturbation: POLR2B
# Warning: POLR2B not in gene list, skipping…
# Generating embedding for perturbation: ANAPC2
# Warning: ANAPC2 not in gene list, skipping…
# Generating embedding for perturbation: ERCC2
# Warning: ERCC2 not in gene list, skipping…
# Generating embedding for perturbation: TOMM22
# Warning: TOMM22 not in gene list, skipping…
# Generating embedding for perturbation: PRIM2
# Warning: PRIM2 not in gene list, skipping…
# Generating embedding for perturbation: SSRP1
# Warning: SSRP1 not in gene list, skipping…
# Generating embedding for perturbation: PRIM1
# Generated embedding for PRIM1: shape (1, 512)
# Generating embedding for perturbation: CWF19L2
# Warning: CWF19L2 not in gene list, skipping…
# Generating embedding for perturbation: MRPS9
# Warning: MRPS9 not in gene list, skipping…
# Generating embedding for perturbation: NDUFB4
# Warning: NDUFB4 not in gene list, skipping…
# Generating embedding for perturbation: SON
# Generated embedding for SON: shape (1, 512)
# Generating embedding for perturbation: SEH1L
# Warning: SEH1L not in gene list, skipping…
# Generating embedding for perturbation: BGLAP
# Warning: BGLAP not in gene list, skipping…
# Generating embedding for perturbation: TCERG1
# Warning: TCERG1 not in gene list, skipping…
# Generating embedding for perturbation: PSMD7
# Warning: PSMD7 not in gene list, skipping…
# Generating embedding for perturbation: UTP15
# Warning: UTP15 not in gene list, skipping…
# Generating embedding for perturbation: MCM2
# Warning: MCM2 not in gene list, skipping…
# Generating embedding for perturbation: DDX23
# Warning: DDX23 not in gene list, skipping…
# Generating embedding for perturbation: SUGT1
# Warning: SUGT1 not in gene list, skipping…
# Generating embedding for perturbation: PAXBP1
# Generated embedding for PAXBP1: shape (1, 512)
# Generating embedding for perturbation: BDP1
# Warning: BDP1 not in gene list, skipping…
# Generating embedding for perturbation: CENPE
# Generated embedding for CENPE: shape (1, 512)
# Generating embedding for perturbation: MZT1
# Warning: MZT1 not in gene list, skipping…
# Generating embedding for perturbation: LSM7
# Warning: LSM7 not in gene list, skipping…
# Generating embedding for perturbation: NRDE2
# Warning: NRDE2 not in gene list, skipping…
# Generating embedding for perturbation: GUCD1
# Warning: GUCD1 not in gene list, skipping…
# Generating embedding for perturbation: NFRKB
# Warning: NFRKB not in gene list, skipping…
# Generating embedding for perturbation: SRPRB
# Generated embedding for SRPRB: shape (1, 512)
# Generating embedding for perturbation: RPS14
# Warning: RPS14 not in gene list, skipping…
# Generating embedding for perturbation: RPL17
# Generated embedding for RPL17: shape (1, 512)
# Generating embedding for perturbation: LSM6
# Warning: LSM6 not in gene list, skipping…
# Generating embedding for perturbation: RTCB
# Warning: RTCB not in gene list, skipping…
# Generating embedding for perturbation: RPS11
# Warning: RPS11 not in gene list, skipping…
# Generating embedding for perturbation: RPL21
# Warning: RPL21 not in gene list, skipping…
# Generating embedding for perturbation: PHAX
# Warning: PHAX not in gene list, skipping…
# Generating embedding for perturbation: UQCC2
# Warning: UQCC2 not in gene list, skipping…
# Generating embedding for perturbation: LSM2
# Warning: LSM2 not in gene list, skipping…
# Generating embedding for perturbation: ATP6V1A
# Warning: ATP6V1A not in gene list, skipping…
# Generating embedding for perturbation: SNRPG
# Warning: SNRPG not in gene list, skipping…
# Generating embedding for perturbation: RPS28
# Generated embedding for RPS28: shape (1, 512)
# Generating embedding for perturbation: PRPF6
# Warning: PRPF6 not in gene list, skipping…
# Generating embedding for perturbation: MRPL38
# Warning: MRPL38 not in gene list, skipping…
# Generating embedding for perturbation: STARD7
# Warning: STARD7 not in gene list, skipping…
# Generating embedding for perturbation: IARS2
# Generated embedding for IARS2: shape (1, 512)
# Generating embedding for perturbation: MED7
# Warning: MED7 not in gene list, skipping…
# Generating embedding for perturbation: CDK1
# Generated embedding for CDK1: shape (1, 512)
# Generating embedding for perturbation: GTF2H1
# Warning: GTF2H1 not in gene list, skipping…
# Generating embedding for perturbation: GAB2
# Warning: GAB2 not in gene list, skipping…
# Generating embedding for perturbation: MAGOH
# Warning: MAGOH not in gene list, skipping…
# Generating embedding for perturbation: CHEK1
# Warning: CHEK1 not in gene list, skipping…
# Generating embedding for perturbation: NSRP1
# Warning: NSRP1 not in gene list, skipping…
# Generating embedding for perturbation: DNTTIP2
# Generated embedding for DNTTIP2: shape (1, 512)
# Generating embedding for perturbation: RPP40
# Warning: RPP40 not in gene list, skipping…
# Generating embedding for perturbation: EIF2B2
# Generated embedding for EIF2B2: shape (1, 512)
# Generating embedding for perturbation: COPS4
# Warning: COPS4 not in gene list, skipping…
# Generating embedding for perturbation: INTS9
# Warning: INTS9 not in gene list, skipping…
# Generating embedding for perturbation: NOL11
# Warning: NOL11 not in gene list, skipping…
# Generating embedding for perturbation: EIF3H
# Warning: EIF3H not in gene list, skipping…
# Generating embedding for perturbation: U2AF1
# Warning: U2AF1 not in gene list, skipping…
# Generating embedding for perturbation: NOL6
# Warning: NOL6 not in gene list, skipping…
# Generating embedding for perturbation: PRPF4
# Warning: PRPF4 not in gene list, skipping…
# Generating embedding for perturbation: SF3A2
# Warning: SF3A2 not in gene list, skipping…
# Generating embedding for perturbation: TXN
# Warning: TXN not in gene list, skipping…
# Generating embedding for perturbation: CSNK1A1
# Warning: CSNK1A1 not in gene list, skipping…
# Generating embedding for perturbation: PPP2R1A
# Warning: PPP2R1A not in gene list, skipping…
# Generating embedding for perturbation: DDX6
# Generated embedding for DDX6: shape (1, 512)
# Generating embedding for perturbation: DDX47
# Warning: DDX47 not in gene list, skipping…
# Generating embedding for perturbation: MRPL10
# Warning: MRPL10 not in gene list, skipping…
# Generating embedding for perturbation: ORC5
# Warning: ORC5 not in gene list, skipping…
# Generating embedding for perturbation: CLP1
# Warning: CLP1 not in gene list, skipping…
# Generating embedding for perturbation: FBL
# Warning: FBL not in gene list, skipping…
# Generating embedding for perturbation: CDC27
# Warning: CDC27 not in gene list, skipping…
# Generating embedding for perturbation: DDX49
# Warning: DDX49 not in gene list, skipping…
# Generating embedding for perturbation: SMN2
# Warning: SMN2 not in gene list, skipping…
# Generating embedding for perturbation: WDR61
# Warning: WDR61 not in gene list, skipping…
# Generating embedding for perturbation: ANKRD11
# Generated embedding for ANKRD11: shape (1, 512)
# Generating embedding for perturbation: DHODH
# Warning: DHODH not in gene list, skipping…
# Generating embedding for perturbation: CCDC86
# Warning: CCDC86 not in gene list, skipping…
# Generating embedding for perturbation: NACA
# Warning: NACA not in gene list, skipping…
# Generating embedding for perturbation: RPS21
# Generated embedding for RPS21: shape (1, 512)
# Generating embedding for perturbation: PSMC6
# Warning: PSMC6 not in gene list, skipping…
# Generating embedding for perturbation: MRPL51
# Warning: MRPL51 not in gene list, skipping…
# Generating embedding for perturbation: ICE1
# Warning: ICE1 not in gene list, skipping…
# Generating embedding for perturbation: POLE
# Warning: POLE not in gene list, skipping…
# Generating embedding for perturbation: NKAP
# Warning: NKAP not in gene list, skipping…
# Generating embedding for perturbation: RPA3
# Warning: RPA3 not in gene list, skipping…
# Generating embedding for perturbation: MAD2L1
# Generated embedding for MAD2L1: shape (1, 512)
# Generating embedding for perturbation: RBM14
# Warning: RBM14 not in gene list, skipping…
# Generating embedding for perturbation: EXOSC9
# Warning: EXOSC9 not in gene list, skipping…
# Generating embedding for perturbation: TSG101
# Warning: TSG101 not in gene list, skipping…
# Generating embedding for perturbation: THAP1
# Warning: THAP1 not in gene list, skipping…
# Generating embedding for perturbation: TRMT10C
# Warning: TRMT10C not in gene list, skipping…
# Generating embedding for perturbation: EIF2B5
# Warning: EIF2B5 not in gene list, skipping…
# Generating embedding for perturbation: LTV1
# Warning: LTV1 not in gene list, skipping…
# Generating embedding for perturbation: VPS29
# Warning: VPS29 not in gene list, skipping…
# Generating embedding for perturbation: KPNB1
# Warning: KPNB1 not in gene list, skipping…
# Generating embedding for perturbation: SDAD1
# Warning: SDAD1 not in gene list, skipping…
# Generating embedding for perturbation: DDX55
# Warning: DDX55 not in gene list, skipping…
# Generating embedding for perturbation: RPL7
# Generated embedding for RPL7: shape (1, 512)
# Generating embedding for perturbation: SARS2
# Warning: SARS2 not in gene list, skipping…
# Generating embedding for perturbation: FNTA
# Warning: FNTA not in gene list, skipping…
# Generating embedding for perturbation: SF3A1
# Warning: SF3A1 not in gene list, skipping…
# Generating embedding for perturbation: CWC15
# Warning: CWC15 not in gene list, skipping…
# Generating embedding for perturbation: UFL1
# Generated embedding for UFL1: shape (1, 512)
# Generating embedding for perturbation: ABCE1
# Warning: ABCE1 not in gene list, skipping…
# Generating embedding for perturbation: CHMP6
# Warning: CHMP6 not in gene list, skipping…
# Generating embedding for perturbation: PPP1R8
# Warning: PPP1R8 not in gene list, skipping…
# Generating embedding for perturbation: MRPL16
# Generated embedding for MRPL16: shape (1, 512)
# Generating embedding for perturbation: RBX1
# Warning: RBX1 not in gene list, skipping…
# Generating embedding for perturbation: BRIX1
# Warning: BRIX1 not in gene list, skipping…
# Generating embedding for perturbation: MRPL39
# Generated embedding for MRPL39: shape (1, 512)
# Generating embedding for perturbation: POLR1B
# Warning: POLR1B not in gene list, skipping…
# Generating embedding for perturbation: SRSF2
# Warning: SRSF2 not in gene list, skipping…
# Generating embedding for perturbation: MPHOSPH10
# Warning: MPHOSPH10 not in gene list, skipping…
# Generating embedding for perturbation: ALDOA
# Generated embedding for ALDOA: shape (1, 512)
# Generating embedding for perturbation: MED19
# Warning: MED19 not in gene list, skipping…
# Generating embedding for perturbation: DHDDS
# Generated embedding for DHDDS: shape (1, 512)
# Generating embedding for perturbation: MED6
# Warning: MED6 not in gene list, skipping…
# Generating embedding for perturbation: MAX
# Warning: MAX not in gene list, skipping…
# Generating embedding for perturbation: DIS3
# Generated embedding for DIS3: shape (1, 512)
# Generating embedding for perturbation: PTCD1
# Warning: PTCD1 not in gene list, skipping…
# Generating embedding for perturbation: TREX2
# Warning: TREX2 not in gene list, skipping…
# Generating embedding for perturbation: HIRA
# Warning: HIRA not in gene list, skipping…
# Generating embedding for perturbation: POP4
# Warning: POP4 not in gene list, skipping…
# Generating embedding for perturbation: SDHC
# Warning: SDHC not in gene list, skipping…
# Generating embedding for perturbation: SSU72
# Warning: SSU72 not in gene list, skipping…
# Generating embedding for perturbation: HARS
# Generated embedding for HARS: shape (1, 512)
# Generating embedding for perturbation: RPL24
# Warning: RPL24 not in gene list, skipping…
# Generating embedding for perturbation: COPB2
# Generated embedding for COPB2: shape (1, 512)
# Generating embedding for perturbation: DR1
# Warning: DR1 not in gene list, skipping…
# Generating embedding for perturbation: COX11
# Warning: COX11 not in gene list, skipping…
# Generating embedding for perturbation: POLD3
# Warning: POLD3 not in gene list, skipping…
# Generating embedding for perturbation: POLR2D
# Warning: POLR2D not in gene list, skipping…
# Generating embedding for perturbation: SRSF1
# Warning: SRSF1 not in gene list, skipping…
# Generating embedding for perturbation: DYNC1H1
# Generated embedding for DYNC1H1: shape (1, 512)
# Generating embedding for perturbation: EIF4G2
# Generated embedding for EIF4G2: shape (1, 512)
# Generating embedding for perturbation: ARCN1
# Generated embedding for ARCN1: shape (1, 512)
# Generating embedding for perturbation: POLR3B
# Warning: POLR3B not in gene list, skipping…
# Generating embedding for perturbation: MYBL2
# Generated embedding for MYBL2: shape (1, 512)
# Generating embedding for perturbation: ZNF574
# Warning: ZNF574 not in gene list, skipping…
# Generating embedding for perturbation: RARS
# Warning: RARS not in gene list, skipping…
# Generating embedding for perturbation: EIF2S2
# Warning: EIF2S2 not in gene list, skipping…
# Generating embedding for perturbation: CCT6A
# Warning: CCT6A not in gene list, skipping…
# Generating embedding for perturbation: TARS
# Generated embedding for TARS: shape (1, 512)
# Generating embedding for perturbation: SETD1A
# Warning: SETD1A not in gene list, skipping…
# Generating embedding for perturbation: THOC2
# Warning: THOC2 not in gene list, skipping…
# Generating embedding for perturbation: HNRNPC
# Warning: HNRNPC not in gene list, skipping…
# Generating embedding for perturbation: DRAP1
# Warning: DRAP1 not in gene list, skipping…
# Generating embedding for perturbation: YEATS4
# Warning: YEATS4 not in gene list, skipping…
# Generating embedding for perturbation: RRP9
# Warning: RRP9 not in gene list, skipping…
# Generating embedding for perturbation: EXOSC8
# Generated embedding for EXOSC8: shape (1, 512)
# Generating embedding for perturbation: TBCB
# Warning: TBCB not in gene list, skipping…
# Generating embedding for perturbation: MRPL53
# Warning: MRPL53 not in gene list, skipping…
# Generating embedding for perturbation: COX15
# Warning: COX15 not in gene list, skipping…
# Generating embedding for perturbation: DNAJC19
# Generated embedding for DNAJC19: shape (1, 512)
# Generating embedding for perturbation: WAC
# Warning: WAC not in gene list, skipping…
# Generating embedding for perturbation: RPS7
# Warning: RPS7 not in gene list, skipping…
# Generating embedding for perturbation: DNAJC8
# Warning: DNAJC8 not in gene list, skipping…
# Generating embedding for perturbation: PMF1
# Warning: PMF1 not in gene list, skipping…
# Generating embedding for perturbation: QARS
# Generated embedding for QARS: shape (1, 512)
# Generating embedding for perturbation: MED17
# Generated embedding for MED17: shape (1, 512)
# Generating embedding for perturbation: GAR1
# Warning: GAR1 not in gene list, skipping…
# Generating embedding for perturbation: WBP11
# Warning: WBP11 not in gene list, skipping…
# Generating embedding for perturbation: MCM10
# Generated embedding for MCM10: shape (1, 512)
# Generating embedding for perturbation: CTDP1
# Warning: CTDP1 not in gene list, skipping…
# Generating embedding for perturbation: PSMD1
# Warning: PSMD1 not in gene list, skipping…
# Generating embedding for perturbation: PLRG1
# Warning: PLRG1 not in gene list, skipping…
# Generating embedding for perturbation: GBF1
# Generated embedding for GBF1: shape (1, 512)
# Generating embedding for perturbation: MED20
# Warning: MED20 not in gene list, skipping…
# Generating embedding for perturbation: CHAF1B
# Warning: CHAF1B not in gene list, skipping…
# Generating embedding for perturbation: DERL2
# Generated embedding for DERL2: shape (1, 512)
# Generating embedding for perturbation: RPL19
# Warning: RPL19 not in gene list, skipping…
# Generating embedding for perturbation: VPS54
# Warning: VPS54 not in gene list, skipping…
# Generating embedding for perturbation: WDR12
# Warning: WDR12 not in gene list, skipping…
# Generating embedding for perturbation: NOP2
# Warning: NOP2 not in gene list, skipping…
# Generating embedding for perturbation: NCBP1
# Warning: NCBP1 not in gene list, skipping…
# Generating embedding for perturbation: NAT10
# Warning: NAT10 not in gene list, skipping…
# Generating embedding for perturbation: MED21
# Warning: MED21 not in gene list, skipping…
# Generating embedding for perturbation: HSF1
# Warning: HSF1 not in gene list, skipping…
# Generating embedding for perturbation: DDX51
# Warning: DDX51 not in gene list, skipping…
# Generating embedding for perturbation: OXA1L
# Warning: OXA1L not in gene list, skipping…
# Generating embedding for perturbation: CCDC59
# Warning: CCDC59 not in gene list, skipping…
# Generating embedding for perturbation: COG3
# Warning: COG3 not in gene list, skipping…
# Generating embedding for perturbation: NIFK
# Warning: NIFK not in gene list, skipping…
# Generating embedding for perturbation: METTL3
# Warning: METTL3 not in gene list, skipping…
# Generating embedding for perturbation: PSMB5
# Warning: PSMB5 not in gene list, skipping…
# Generating embedding for perturbation: PELO
# Generated embedding for PELO: shape (1, 512)
# Generating embedding for perturbation: HAUS4
# Warning: HAUS4 not in gene list, skipping…
# Generating embedding for perturbation: SART3
# Warning: SART3 not in gene list, skipping…
# Generating embedding for perturbation: EXOSC7
# Warning: EXOSC7 not in gene list, skipping…
# Generating embedding for perturbation: CUL2
# Warning: CUL2 not in gene list, skipping…
# Generating embedding for perturbation: RPL32
# Generated embedding for RPL32: shape (1, 512)
# Generating embedding for perturbation: PRELID3B
# Warning: PRELID3B not in gene list, skipping…
# Generating embedding for perturbation: RUVBL1
# Warning: RUVBL1 not in gene list, skipping…
# Generating embedding for perturbation: TEX10
# Warning: TEX10 not in gene list, skipping…
# Generating embedding for perturbation: GTF2E1
# Warning: GTF2E1 not in gene list, skipping…
# Generating embedding for perturbation: RPL30
# Warning: RPL30 not in gene list, skipping…
# Generating embedding for perturbation: RCL1
# Warning: RCL1 not in gene list, skipping…
# Generating embedding for perturbation: RBBP8
# Warning: RBBP8 not in gene list, skipping…
# Generating embedding for perturbation: MAT2A
# Generated embedding for MAT2A: shape (1, 512)
# Generating embedding for perturbation: LRPPRC
# Generated embedding for LRPPRC: shape (1, 512)
# Generating embedding for perturbation: DDX54
# Warning: DDX54 not in gene list, skipping…
# Generating embedding for perturbation: CASP8AP2
# Warning: CASP8AP2 not in gene list, skipping…
# Generating embedding for perturbation: E4F1
# Warning: E4F1 not in gene list, skipping…
# Generating embedding for perturbation: MRPL35
# Warning: MRPL35 not in gene list, skipping…
# Generating embedding for perturbation: RPS17
# Warning: RPS17 not in gene list, skipping…
# Generating embedding for perturbation: RPL36
# Warning: RPL36 not in gene list, skipping…
# Generating embedding for perturbation: SF3B5
# Warning: SF3B5 not in gene list, skipping…
# Generating embedding for perturbation: RBMX2
# Warning: RBMX2 not in gene list, skipping…
# Generating embedding for perturbation: EIF3D
# Generated embedding for EIF3D: shape (1, 512)
# Generating embedding for perturbation: CCT4
# Warning: CCT4 not in gene list, skipping…
# Generating embedding for perturbation: EIF3I
# Warning: EIF3I not in gene list, skipping…
# Generating embedding for perturbation: RNPS1
# Warning: RNPS1 not in gene list, skipping…
# Generating embedding for perturbation: CDC16
# Warning: CDC16 not in gene list, skipping…
# Generating embedding for perturbation: PHB2
# Warning: PHB2 not in gene list, skipping…
# Generating embedding for perturbation: PDRG1
# Generated embedding for PDRG1: shape (1, 512)
# Generating embedding for perturbation: GINS3
# Warning: GINS3 not in gene list, skipping…
# Generating embedding for perturbation: RIOK1
# Warning: RIOK1 not in gene list, skipping…
# Generating embedding for perturbation: XAB2
# Warning: XAB2 not in gene list, skipping…
# Generating embedding for perturbation: EBNA1BP2
# Warning: EBNA1BP2 not in gene list, skipping…
# Generating embedding for perturbation: ETF1
# Warning: ETF1 not in gene list, skipping…
# Generating embedding for perturbation: RPL4
# Warning: RPL4 not in gene list, skipping…
# Generating embedding for perturbation: ORC1
# Warning: ORC1 not in gene list, skipping…
# Generating embedding for perturbation: EIF5A
# Warning: EIF5A not in gene list, skipping…
# Generating embedding for perturbation: SF3B2
# Generated embedding for SF3B2: shape (1, 512)
# Generating embedding for perturbation: TRMT112
# Warning: TRMT112 not in gene list, skipping…
# Generating embedding for perturbation: INTS1
# Warning: INTS1 not in gene list, skipping…
# Generating embedding for perturbation: MRPS22
# Warning: MRPS22 not in gene list, skipping…
# Generating embedding for perturbation: NMD3
# Warning: NMD3 not in gene list, skipping…
# Generating embedding for perturbation: GINS2
# Generated embedding for GINS2: shape (1, 512)
# Generating embedding for perturbation: MOB4
# Warning: MOB4 not in gene list, skipping…
# Generating embedding for perturbation: UXT
# Warning: UXT not in gene list, skipping…
# Generating embedding for perturbation: ACTR8
# Warning: ACTR8 not in gene list, skipping…
# Generating embedding for perturbation: EXOSC2
# Warning: EXOSC2 not in gene list, skipping…
# Generating embedding for perturbation: MRPS2
# Warning: MRPS2 not in gene list, skipping…
# Generating embedding for perturbation: MRPL33
# Warning: MRPL33 not in gene list, skipping…
# Generating embedding for perturbation: MRPS10
# Warning: MRPS10 not in gene list, skipping…
# Generating embedding for perturbation: ALG13
# Warning: ALG13 not in gene list, skipping…
# Generating embedding for perturbation: CPSF3
# Warning: CPSF3 not in gene list, skipping…
# Generating embedding for perturbation: PCID2
# Warning: PCID2 not in gene list, skipping…
# Generating embedding for perturbation: DDX10
# Generated embedding for DDX10: shape (1, 512)
# Generating embedding for perturbation: AATF
# Warning: AATF not in gene list, skipping…
# Generating embedding for perturbation: ERCC3
# Warning: ERCC3 not in gene list, skipping…
# Generating embedding for perturbation: CCNK
# Warning: CCNK not in gene list, skipping…
# Generating embedding for perturbation: RBM42
# Warning: RBM42 not in gene list, skipping…
# Generating embedding for perturbation: CDC40
# Warning: CDC40 not in gene list, skipping…
# Generating embedding for perturbation: POLR1A
# Warning: POLR1A not in gene list, skipping…
# Generating embedding for perturbation: UBAP1
# Warning: UBAP1 not in gene list, skipping…
# Generating embedding for perturbation: TOP1
# Warning: TOP1 not in gene list, skipping…
# Generating embedding for perturbation: RPL23A
# Warning: RPL23A not in gene list, skipping…
# Generating embedding for perturbation: PPP1R11
# Warning: PPP1R11 not in gene list, skipping…
# Generating embedding for perturbation: POLR2I
# Warning: POLR2I not in gene list, skipping…
# Generating embedding for perturbation: RPF2
# Warning: RPF2 not in gene list, skipping…
# Generating embedding for perturbation: RPS15A
# Generated embedding for RPS15A: shape (1, 512)
# Generating embedding for perturbation: SF3B3
# Warning: SF3B3 not in gene list, skipping…
# Generating embedding for perturbation: SMC2
# Warning: SMC2 not in gene list, skipping…
# Generating embedding for perturbation: SEC61G
# Generated embedding for SEC61G: shape (1, 512)
# Generating embedding for perturbation: NLE1
# Warning: NLE1 not in gene list, skipping…
# Generating embedding for perturbation: DHX36
# Warning: DHX36 not in gene list, skipping…
# Generating embedding for perturbation: YTHDC1
# Warning: YTHDC1 not in gene list, skipping…
# Generating embedding for perturbation: MARS2
# Warning: MARS2 not in gene list, skipping…
# Generating embedding for perturbation: SNW1
# Warning: SNW1 not in gene list, skipping…
# Generating embedding for perturbation: NUP85
# Warning: NUP85 not in gene list, skipping…
# Generating embedding for perturbation: MRPL54
# Warning: MRPL54 not in gene list, skipping…
# Generating embedding for perturbation: WDHD1
# Warning: WDHD1 not in gene list, skipping…
# Generating embedding for perturbation: PAF1
# Warning: PAF1 not in gene list, skipping…
# Generating embedding for perturbation: PSMD12
# Generated embedding for PSMD12: shape (1, 512)
# Generating embedding for perturbation: POLRMT
# Warning: POLRMT not in gene list, skipping…
# Generating embedding for perturbation: DCUN1D5
# Warning: DCUN1D5 not in gene list, skipping…
# Generating embedding for perturbation: PSMD6
# Warning: PSMD6 not in gene list, skipping…
# Generating embedding for perturbation: NDUFB8
# Warning: NDUFB8 not in gene list, skipping…
# Generating embedding for perturbation: DHX16
# Warning: DHX16 not in gene list, skipping…
# Generating embedding for perturbation: LETM1
# Warning: LETM1 not in gene list, skipping…
# Generating embedding for perturbation: PSMB3
# Warning: PSMB3 not in gene list, skipping…
# Generating embedding for perturbation: RANGAP1
# Warning: RANGAP1 not in gene list, skipping…
# Generating embedding for perturbation: URB2
# Warning: URB2 not in gene list, skipping…
# Generating embedding for perturbation: MMS22L
# Warning: MMS22L not in gene list, skipping…
# Generating embedding for perturbation: BOP1
# Warning: BOP1 not in gene list, skipping…
# Generating embedding for perturbation: CLTC
# Warning: CLTC not in gene list, skipping…
# Generating embedding for perturbation: DDX56
# Warning: DDX56 not in gene list, skipping…
# Generating embedding for perturbation: NOL8
# Generated embedding for NOL8: shape (1, 512)
# Generating embedding for perturbation: FCF1
# Warning: FCF1 not in gene list, skipping…
# Generating embedding for perturbation: LSM4
# Warning: LSM4 not in gene list, skipping…
# Generating embedding for perturbation: NAA10
# Warning: NAA10 not in gene list, skipping…
# Generating embedding for perturbation: IGBP1
# Generated embedding for IGBP1: shape (1, 512)
# Generating embedding for perturbation: SNRNP27
# Warning: SNRNP27 not in gene list, skipping…
# Generating embedding for perturbation: SRP54
# Warning: SRP54 not in gene list, skipping…
# Generating embedding for perturbation: SMU1
# Warning: SMU1 not in gene list, skipping…
# Generating embedding for perturbation: TUT1
# Warning: TUT1 not in gene list, skipping…
# Generating embedding for perturbation: GFM1
# Warning: GFM1 not in gene list, skipping…
# Generating embedding for perturbation: DNAJA3
# Warning: DNAJA3 not in gene list, skipping…
# Generating embedding for perturbation: ACTB
# Generated embedding for ACTB: shape (1, 512)
# Generating embedding for perturbation: SNRNP25
# Generated embedding for SNRNP25: shape (1, 512)
# Generating embedding for perturbation: TMX2
# Warning: TMX2 not in gene list, skipping…
# Generating embedding for perturbation: POLR2E
# Warning: POLR2E not in gene list, skipping…
# Generating embedding for perturbation: EIF5
# Warning: EIF5 not in gene list, skipping…
# Generating embedding for perturbation: CCT3
# Warning: CCT3 not in gene list, skipping…
# Generating embedding for perturbation: TAF7
# Generated embedding for TAF7: shape (1, 512)
# Generating embedding for perturbation: MRPL24
# Warning: MRPL24 not in gene list, skipping…
# Generating embedding for perturbation: SNRPD1
# Warning: SNRPD1 not in gene list, skipping…
# Generating embedding for perturbation: PHB
# Warning: PHB not in gene list, skipping…
# Generating embedding for perturbation: INTS5
# Warning: INTS5 not in gene list, skipping…
# Generating embedding for perturbation: KCTD10
# Generated embedding for KCTD10: shape (1, 512)
# Generating embedding for perturbation: MRPL43
# Warning: MRPL43 not in gene list, skipping…
# Generating embedding for perturbation: SBNO1
# Warning: SBNO1 not in gene list, skipping…
# Generating embedding for perturbation: PRMT1
# Warning: PRMT1 not in gene list, skipping…
# Generating embedding for perturbation: JAZF1
# Warning: JAZF1 not in gene list, skipping…
# Generating embedding for perturbation: HYPK
# Warning: HYPK not in gene list, skipping…
# Generating embedding for perturbation: MRPL14
# Warning: MRPL14 not in gene list, skipping…
# Generating embedding for perturbation: CIAPIN1
# Warning: CIAPIN1 not in gene list, skipping…
# Generating embedding for perturbation: ALYREF
# Warning: ALYREF not in gene list, skipping…
# Generating embedding for perturbation: MED22
# Warning: MED22 not in gene list, skipping…
# Generating embedding for perturbation: RFC3
# Warning: RFC3 not in gene list, skipping…
# Generating embedding for perturbation: ATF5
# Generated embedding for ATF5: shape (1, 512)
# Generating embedding for perturbation: DICER1
# Generated embedding for DICER1: shape (1, 512)
# Generating embedding for perturbation: CHMP2A
# Warning: CHMP2A not in gene list, skipping…
# Generating embedding for perturbation: MRPS26
# Warning: MRPS26 not in gene list, skipping…
# Generating embedding for perturbation: RCC1
# Warning: RCC1 not in gene list, skipping…
# Generating embedding for perturbation: PFN1
# Warning: PFN1 not in gene list, skipping…
# Generating embedding for perturbation: NEDD1
# Warning: NEDD1 not in gene list, skipping…
# Generating embedding for perturbation: COPS6
# Warning: COPS6 not in gene list, skipping…
# Generating embedding for perturbation: COX7C
# Warning: COX7C not in gene list, skipping…
# Generating embedding for perturbation: DDX5
# Generated embedding for DDX5: shape (1, 512)
# Generating embedding for perturbation: THG1L
# Warning: THG1L not in gene list, skipping…
# Generating embedding for perturbation: TIMM13
# Warning: TIMM13 not in gene list, skipping…
# Generating embedding for perturbation: PSMG3
# Warning: PSMG3 not in gene list, skipping…
# Generating embedding for perturbation: RRS1
# Warning: RRS1 not in gene list, skipping…
# Generating embedding for perturbation: TERF2
# Generated embedding for TERF2: shape (1, 512)
# Generating embedding for perturbation: PRMT5
# Warning: PRMT5 not in gene list, skipping…
# Generating embedding for perturbation: NDUFA6
# Warning: NDUFA6 not in gene list, skipping…
# Generating embedding for perturbation: RPUSD4
# Warning: RPUSD4 not in gene list, skipping…
# Generating embedding for perturbation: AKIRIN2
# Generated embedding for AKIRIN2: shape (1, 512)
# Generating embedding for perturbation: MRPL22
# Warning: MRPL22 not in gene list, skipping…
# Generating embedding for perturbation: EIF2S1
# Generated embedding for EIF2S1: shape (1, 512)
# Generating embedding for perturbation: EEF2
# Generated embedding for EEF2: shape (1, 512)
# Generating embedding for perturbation: MNAT1
# Warning: MNAT1 not in gene list, skipping…
# Generating embedding for perturbation: LARS
# Generated embedding for LARS: shape (1, 512)
# Generating embedding for perturbation: CUL1
# Warning: CUL1 not in gene list, skipping…
# Generating embedding for perturbation: EXOSC4
# Generated embedding for EXOSC4: shape (1, 512)
# Generating embedding for perturbation: RRP1
# Warning: RRP1 not in gene list, skipping…
# Generating embedding for perturbation: POLR3E
# Warning: POLR3E not in gene list, skipping…
# Generating embedding for perturbation: KRI1
# Warning: KRI1 not in gene list, skipping…
# Generating embedding for perturbation: RNF20
# Warning: RNF20 not in gene list, skipping…
# Generating embedding for perturbation: ZNF335
# Warning: ZNF335 not in gene list, skipping…
# Generating embedding for perturbation: NOC3L
# Warning: NOC3L not in gene list, skipping…
# Generating embedding for perturbation: GPN3
# Warning: GPN3 not in gene list, skipping…
# Generating embedding for perturbation: TPX2
# Generated embedding for TPX2: shape (1, 512)
# Generating embedding for perturbation: NUP62
# Warning: NUP62 not in gene list, skipping…
# Generating embedding for perturbation: RPL13A
# Generated embedding for RPL13A: shape (1, 512)
# Generating embedding for perturbation: SNAPC5
# Generated embedding for SNAPC5: shape (1, 512)
# Generating embedding for perturbation: BANP
# Warning: BANP not in gene list, skipping…
# Generating embedding for perturbation: AAMP
# Warning: AAMP not in gene list, skipping…
# Generating embedding for perturbation: GPKOW
# Warning: GPKOW not in gene list, skipping…
# Generating embedding for perturbation: CHMP3
# Warning: CHMP3 not in gene list, skipping…
# Generating embedding for perturbation: USP5
# Warning: USP5 not in gene list, skipping…
# Generating embedding for perturbation: POLR2F
# Warning: POLR2F not in gene list, skipping…
# Generating embedding for perturbation: PPP1CA
# Warning: PPP1CA not in gene list, skipping…
# Generating embedding for perturbation: KANSL1
# Warning: KANSL1 not in gene list, skipping…
# Generating embedding for perturbation: NUDT21
# Warning: NUDT21 not in gene list, skipping…
# Generating embedding for perturbation: MCM6
# Warning: MCM6 not in gene list, skipping…
# Generating embedding for perturbation: MRPL27
# Warning: MRPL27 not in gene list, skipping…
# Generating embedding for perturbation: USP36
# Warning: USP36 not in gene list, skipping…
# Generating embedding for perturbation: NARS
# Warning: NARS not in gene list, skipping…
# Generating embedding for perturbation: PTBP1
# Warning: PTBP1 not in gene list, skipping…
# Generating embedding for perturbation: TAF8
# Warning: TAF8 not in gene list, skipping…
# Generating embedding for perturbation: MRPL3
# Warning: MRPL3 not in gene list, skipping…
# Generating embedding for perturbation: THOC1
# Warning: THOC1 not in gene list, skipping…
# Generating embedding for perturbation: RPL8
# Warning: RPL8 not in gene list, skipping…
# Generating embedding for perturbation: ATRIP
# Warning: ATRIP not in gene list, skipping…
# ...
# Warning: CCT8 not in gene list, skipping…
# Generating embedding for perturbation: RABGGTA
# Warning: RABGGTA not in gene list, skipping…
# Generating embedding for perturbation: CPSF6
# Warning: CPSF6 not in gene list, skipping…
# Generating embedding for perturbation: HAUS5
# Warning: HAUS5 not in gene list, skipping…
# Generating embedding for perturbation: NOLC1
# Generated embedding for NOLC1: shape (1, 512)
# Generating embedding for perturbation: WDR24
# Warning: WDR24 not in gene list, skipping…
# Generating embedding for perturbation: NOP58
# Warning: NOP58 not in gene list, skipping…
# Generating embedding for perturbation: INTS4
# Warning: INTS4 not in gene list, skipping…
# Generating embedding for perturbation: DIMT1
# Warning: DIMT1 not in gene list, skipping…
# Generating embedding for perturbation: RPP30
# Warning: RPP30 not in gene list, skipping…
# Generating embedding for perturbation: PRPF19
# Warning: PRPF19 not in gene list, skipping…
# Generating embedding for perturbation: SYMPK
# Warning: SYMPK not in gene list, skipping…
# Generating embedding for perturbation: PRPF3
# Generated embedding for PRPF3: shape (1, 512)
# Generating embedding for perturbation: GTF2A2
# Warning: GTF2A2 not in gene list, skipping…
# Generating embedding for perturbation: SKA3
# Warning: SKA3 not in gene list, skipping…
# Generating embedding for perturbation: DDX21
# Warning: DDX21 not in gene list, skipping…
# Generating embedding for perturbation: ATP1A1
# Warning: ATP1A1 not in gene list, skipping…
# Generating embedding for perturbation: SRP68
# Generated embedding for SRP68: shape (1, 512)
# Generating embedding for perturbation: CLNS1A
# Warning: CLNS1A not in gene list, skipping…
# Generating embedding for perturbation: GSPT1
# Generated embedding for GSPT1: shape (1, 512)
# Generating embedding for perturbation: NDUFA8
# Warning: NDUFA8 not in gene list, skipping…
# Generating embedding for perturbation: PET117
# Warning: PET117 not in gene list, skipping…
# Generating embedding for perturbation: VPS72
# Warning: VPS72 not in gene list, skipping…
# Generating embedding for perturbation: LSM11
# Warning: LSM11 not in gene list, skipping…
# Generating embedding for perturbation: NUFIP1
# Warning: NUFIP1 not in gene list, skipping…
# Generating embedding for perturbation: UQCRB
# Generated embedding for UQCRB: shape (1, 512)
# Generating embedding for perturbation: DNAJC17
# Warning: DNAJC17 not in gene list, skipping…
# Generating embedding for perturbation: RBM19
# Warning: RBM19 not in gene list, skipping…
# Generating embedding for perturbation: MRPL37
# Warning: MRPL37 not in gene list, skipping…
# Generating embedding for perturbation: RPS5
# Warning: RPS5 not in gene list, skipping…
# Generating embedding for perturbation: NOB1
# Warning: NOB1 not in gene list, skipping…
# Generating embedding for perturbation: SDC1
# Generated embedding for SDC1: shape (1, 512)
# Generating embedding for perturbation: MTPAP
# Warning: MTPAP not in gene list, skipping…
# Generating embedding for perturbation: HBS1L
# Generated embedding for HBS1L: shape (1, 512)
# Generating embedding for perturbation: CUL7
# Warning: CUL7 not in gene list, skipping…
# Generating embedding for perturbation: MRPL13
# Warning: MRPL13 not in gene list, skipping…
# Generating embedding for perturbation: SLC7A6OS
# Warning: SLC7A6OS not in gene list, skipping…
# Generating embedding for perturbation: ARIH1
# Warning: ARIH1 not in gene list, skipping…
# Generating embedding for perturbation: PELP1
# Warning: PELP1 not in gene list, skipping…
# Generating embedding for perturbation: DDX41
# Warning: DDX41 not in gene list, skipping…
# Generating embedding for perturbation: RPL12
# Generated embedding for RPL12: shape (1, 512)
# Generating embedding for perturbation: SKP1
# Warning: SKP1 not in gene list, skipping…
# Generating embedding for perturbation: NUP133
# Warning: NUP133 not in gene list, skipping…
# Generating embedding for perturbation: TWISTNB
# Generated embedding for TWISTNB: shape (1, 512)
# Generating embedding for perturbation: EPRS
# Generated embedding for EPRS: shape (1, 512)
# Generating embedding for perturbation: KARS
# Warning: KARS not in gene list, skipping…
# Generating embedding for perturbation: HSCB
# Warning: HSCB not in gene list, skipping…
# Generating embedding for perturbation: PES1
# Warning: PES1 not in gene list, skipping…
# Generating embedding for perturbation: HNRNPU
# Generated embedding for HNRNPU: shape (1, 512)
# Generating embedding for perturbation: SAP130
# Warning: SAP130 not in gene list, skipping…
# Generating embedding for perturbation: TAF5
# Warning: TAF5 not in gene list, skipping…
# Generating embedding for perturbation: NUP88
# Warning: NUP88 not in gene list, skipping…
# Generating embedding for perturbation: PSMA1
# Warning: PSMA1 not in gene list, skipping…
# Generating embedding for perturbation: DAD1
# Generated embedding for DAD1: shape (1, 512)
# Generating embedding for perturbation: SNAPC1
# Warning: SNAPC1 not in gene list, skipping…
# Generating embedding for perturbation: MRPS18A
# Warning: MRPS18A not in gene list, skipping…
# Generating embedding for perturbation: POLD2
# Warning: POLD2 not in gene list, skipping…
# Generating embedding for perturbation: TIMM44
# Generated embedding for TIMM44: shape (1, 512)
# Generating embedding for perturbation: DDX59
# Warning: DDX59 not in gene list, skipping…
# Generating embedding for perturbation: CLSPN
# Generated embedding for CLSPN: shape (1, 512)
# Generating embedding for perturbation: MED4
# Warning: MED4 not in gene list, skipping…
# Generating embedding for perturbation: INO80
# Warning: INO80 not in gene list, skipping…
# Generating embedding for perturbation: HGS
# Warning: HGS not in gene list, skipping…
# Generating embedding for perturbation: UQCRFS1
# Warning: UQCRFS1 not in gene list, skipping…
# Generating embedding for perturbation: PDCD7
# Warning: PDCD7 not in gene list, skipping…
# Generating embedding for perturbation: COX17
# Warning: COX17 not in gene list, skipping…
# Generating embedding for perturbation: UTP3
# Warning: UTP3 not in gene list, skipping…
# Generating embedding for perturbation: NOP14
# Generated embedding for NOP14: shape (1, 512)
# Generating embedding for perturbation: NFS1
# Warning: NFS1 not in gene list, skipping…
# Generating embedding for perturbation: NCKAP1
# Warning: NCKAP1 not in gene list, skipping…
# Generating embedding for perturbation: C12orf45
# Warning: C12orf45 not in gene list, skipping…
# Generating embedding for perturbation: INTS7
# Warning: INTS7 not in gene list, skipping…
# Generating embedding for perturbation: ILF2
# Warning: ILF2 not in gene list, skipping…
# Generating embedding for perturbation: XRCC5
# Generated embedding for XRCC5: shape (1, 512)
# Generating embedding for perturbation: DHX33
# Warning: DHX33 not in gene list, skipping…
# Generating embedding for perturbation: DMAP1
# Warning: DMAP1 not in gene list, skipping…
# Generating embedding for perturbation: UPF1
# Warning: UPF1 not in gene list, skipping…
# Generating embedding for perturbation: EXOSC5
# Warning: EXOSC5 not in gene list, skipping…
# Generating embedding for perturbation: RPS15
# Warning: RPS15 not in gene list, skipping…
# Generating embedding for perturbation: GMPS
# Warning: GMPS not in gene list, skipping…
# Generating embedding for perturbation: CENPC
# Generated embedding for CENPC: shape (1, 512)
# Generating embedding for perturbation: RBBP6
# Warning: RBBP6 not in gene list, skipping…
# Generating embedding for perturbation: NOM1
# Generated embedding for NOM1: shape (1, 512)
# Generating embedding for perturbation: RFC5
# Warning: RFC5 not in gene list, skipping…
# Generating embedding for perturbation: RRP7A
# Warning: RRP7A not in gene list, skipping…
# Generating embedding for perturbation: TRPM7
# Warning: TRPM7 not in gene list, skipping…
# Generating embedding for perturbation: NELFA
# Warning: NELFA not in gene list, skipping…
# Generating embedding for perturbation: RRN3
# Warning: RRN3 not in gene list, skipping…
# Generating embedding for perturbation: DARS
# Generated embedding for DARS: shape (1, 512)
# Generating embedding for perturbation: METTL16
# Warning: METTL16 not in gene list, skipping…
# Generating embedding for perturbation: UTP6
# Warning: UTP6 not in gene list, skipping…
# Generating embedding for perturbation: MED29
# Warning: MED29 not in gene list, skipping…
# Generating embedding for perturbation: FARSA
# Warning: FARSA not in gene list, skipping…
# Generating embedding for perturbation: GPN1
# Warning: GPN1 not in gene list, skipping…
# Generating embedding for perturbation: NOL12
# Warning: NOL12 not in gene list, skipping…
# Generating embedding for perturbation: RBM48
# Warning: RBM48 not in gene list, skipping…
# Generating embedding for perturbation: PSMA6
# Warning: PSMA6 not in gene list, skipping…
# Generating embedding for perturbation: SRSF3
# Warning: SRSF3 not in gene list, skipping…
# Generating embedding for perturbation: OGT
# Generated embedding for OGT: shape (1, 512)
# Generating embedding for perturbation: HNRNPL
# Warning: HNRNPL not in gene list, skipping…
# Generating embedding for perturbation: RNPC3
# Warning: RNPC3 not in gene list, skipping…
# Generating embedding for perturbation: DUT
# Generated embedding for DUT: shape (1, 512)
# Generating embedding for perturbation: TBL3
# Warning: TBL3 not in gene list, skipping…
# Generating embedding for perturbation: CCDC84
# Warning: CCDC84 not in gene list, skipping…
# Generating embedding for perturbation: MAU2
# Warning: MAU2 not in gene list, skipping…
# Generating embedding for perturbation: CWC22
# Warning: CWC22 not in gene list, skipping…
# Generating embedding for perturbation: URI1
# Warning: URI1 not in gene list, skipping…
# Generating embedding for perturbation: CTNNBL1
# Warning: CTNNBL1 not in gene list, skipping…
# Generating embedding for perturbation: VPS28
# Warning: VPS28 not in gene list, skipping…
# Generating embedding for perturbation: DDX20
# Warning: DDX20 not in gene list, skipping…
# Generating embedding for perturbation: PDAP1
# Warning: PDAP1 not in gene list, skipping…
# Generating embedding for perturbation: VPS35
# Warning: VPS35 not in gene list, skipping…
# Generating embedding for perturbation: PWP2
# Warning: PWP2 not in gene list, skipping…
# Generating embedding for perturbation: POP5
# Warning: POP5 not in gene list, skipping…
# Generating embedding for perturbation: SF1
# Warning: SF1 not in gene list, skipping…
# Generating embedding for perturbation: XRN2
# Warning: XRN2 not in gene list, skipping…
# Generating embedding for perturbation: AARS
# Generated embedding for AARS: shape (1, 512)
# Generating embedding for perturbation: PRPF31
# Warning: PRPF31 not in gene list, skipping…
# Generating embedding for perturbation: EIF3G
# Warning: EIF3G not in gene list, skipping…
# Generating embedding for perturbation: PSMC3
# Warning: PSMC3 not in gene list, skipping…
# Generating embedding for perturbation: PGPEP1
# Generated embedding for PGPEP1: shape (1, 512)
# Generating embedding for perturbation: IARS
# Generated embedding for IARS: shape (1, 512)
# Generating embedding for perturbation: OPA1
# Generated embedding for OPA1: shape (1, 512)
# Generating embedding for perturbation: RPL7L1
# Warning: RPL7L1 not in gene list, skipping…
# Generating embedding for perturbation: SNIP1
# Warning: SNIP1 not in gene list, skipping…
# Generating embedding for perturbation: SARS
# Generated embedding for SARS: shape (1, 512)
# Generating embedding for perturbation: EXOC7
# Warning: EXOC7 not in gene list, skipping…
# Generating embedding for perturbation: FAU
# Warning: FAU not in gene list, skipping…
# Generating embedding for perturbation: CHAF1A
# Generated embedding for CHAF1A: shape (1, 512)
# Generating embedding for perturbation: GPN2
# Warning: GPN2 not in gene list, skipping…
# Generating embedding for perturbation: THAP11
# Warning: THAP11 not in gene list, skipping…
# Generating embedding for perturbation: IPO13
# Warning: IPO13 not in gene list, skipping…
# Generating embedding for perturbation: CACTIN
# Warning: CACTIN not in gene list, skipping…
# Generating embedding for perturbation: UQCRC2
# Warning: UQCRC2 not in gene list, skipping…
# Generating embedding for perturbation: PSMB2
# Warning: PSMB2 not in gene list, skipping…
# Generating embedding for perturbation: BMS1
# Warning: BMS1 not in gene list, skipping…
# Generating embedding for perturbation: BUD31
# Warning: BUD31 not in gene list, skipping…
# Generating embedding for perturbation: SNRPC
# Warning: SNRPC not in gene list, skipping…
# Generating embedding for perturbation: RPS2
# Warning: RPS2 not in gene list, skipping…
#
# Perturbation Embeddings Generated:
# HNRNPH1: (1, 512)
# RIOK2: (1, 512)
# EIF3E: (1, 512)
# WDR36: (1, 512)
# NBAS: (1, 512)
# CKAP5: (1, 512)
# RPS6: (1, 512)
# FBXO5: (1, 512)
# EIF4G1: (1, 512)
# HSPA9: (1, 512)
# SLU7: (1, 512)
# DDX46: (1, 512)
# NOP16: (1, 512)
# POLA1: (1, 512)
# SLC7A5: (1, 512)
# RPS27: (1, 512)
# RSL24D1: (1, 512)
# PCF11: (1, 512)
# RPS26: (1, 512)
# EIF3A: (1, 512)
# RPL37: (1, 512)
# ZNHIT6: (1, 512)
# NUF2: (1, 512)
# BUB3: (1, 512)
# SAMM50: (1, 512)
# MFAP1: (1, 512)
# PSMC2: (1, 512)
# RPS24: (1, 512)
# ARGLU1: (1, 512)
# HSPA5: (1, 512)
# MCM4: (1, 512)
# PSMD11: (1, 512)
# SRP72: (1, 512)
# SFPQ: (1, 512)
# SDE2: (1, 512)
# RPL34: (1, 512)
# RPS29: (1, 512)
# GARS: (1, 512)
# CHD4: (1, 512)
# XPO1: (1, 512)
# RPS10: (1, 512)
# PRIM1: (1, 512)
# SON: (1, 512)
# PAXBP1: (1, 512)
# CENPE: (1, 512)
# SRPRB: (1, 512)
# RPL17: (1, 512)
# RPS28: (1, 512)
# IARS2: (1, 512)
# CDK1: (1, 512)
# DNTTIP2: (1, 512)
# EIF2B2: (1, 512)
# DDX6: (1, 512)
# ANKRD11: (1, 512)
# RPS21: (1, 512)
# MAD2L1: (1, 512)
# RPL7: (1, 512)
# UFL1: (1, 512)
# MRPL16: (1, 512)
# MRPL39: (1, 512)
# ALDOA: (1, 512)
# DHDDS: (1, 512)
# DIS3: (1, 512)
# HARS: (1, 512)
# COPB2: (1, 512)
# DYNC1H1: (1, 512)
# EIF4G2: (1, 512)
# ARCN1: (1, 512)
# MYBL2: (1, 512)
# TARS: (1, 512)
# EXOSC8: (1, 512)
# DNAJC19: (1, 512)
# QARS: (1, 512)
# MED17: (1, 512)
# MCM10: (1, 512)
# GBF1: (1, 512)
# DERL2: (1, 512)
# PELO: (1, 512)
# RPL32: (1, 512)
# MAT2A: (1, 512)
# LRPPRC: (1, 512)
# EIF3D: (1, 512)
# PDRG1: (1, 512)
# SF3B2: (1, 512)
# GINS2: (1, 512)
# DDX10: (1, 512)
# RPS15A: (1, 512)
# SEC61G: (1, 512)
# PSMD12: (1, 512)
# NOL8: (1, 512)
# IGBP1: (1, 512)
# ACTB: (1, 512)
# SNRNP25: (1, 512)
# TAF7: (1, 512)
# KCTD10: (1, 512)
# ATF5: (1, 512)
# DICER1: (1, 512)
# DDX5: (1, 512)
# TERF2: (1, 512)
# AKIRIN2: (1, 512)
# EIF2S1: (1, 512)
# EEF2: (1, 512)
# LARS: (1, 512)
# EXOSC4: (1, 512)
# TPX2: (1, 512)
# RPL13A: (1, 512)
# SNAPC5: (1, 512)
# SYF2: (1, 512)
# CEP192: (1, 512)
# RPL26: (1, 512)
# CDC6: (1, 512)
# COPZ1: (1, 512)
# SLBP: (1, 512)
# HSPA8: (1, 512)
# NEDD8: (1, 512)
# HEATR1: (1, 512)
# EIF2B3: (1, 512)
# RPAP2: (1, 512)
# RPS23: (1, 512)
# PNN: (1, 512)
# TTI1: (1, 512)
# MDN1: (1, 512)
# CHERP: (1, 512)
# CD3EAP: (1, 512)
# RPL36A: (1, 512)
# HSPE1: (1, 512)
# RPL10: (1, 512)
# TMSB10: (1, 512)
# GTF2B: (1, 512)
# RPL38: (1, 512)
# DTL: (1, 512)
# NCL: (1, 512)
# RPL39: (1, 512)
# SRRM2: (1, 512)
# CTR9: (1, 512)
# POLR2A: (1, 512)
# RPL37A: (1, 512)
# RBM28: (1, 512)
# ATP6V1B2: (1, 512)
# SUPT16H: (1, 512)
# MARS: (1, 512)
# EIF2S3: (1, 512)
# MVD: (1, 512)
# CDC73: (1, 512)
# SMC1A: (1, 512)
# GNL3: (1, 512)
# NDC80: (1, 512)
# RPS12: (1, 512)
# WDR3: (1, 512)
# WDR43: (1, 512)
# RPS18: (1, 512)
# UFM1: (1, 512)
# GATA1: (1, 512)
# KIF20A: (1, 512)
# EIF2B4: (1, 512)
# RPS10-NUDT3: (1, 512)
# RPS27A: (1, 512)
# GTF2A1: (1, 512)
# MCM3: (1, 512)
# GRB2: (1, 512)
# CSTF3: (1, 512)
# COPB1: (1, 512)
# RPS3A: (1, 512)
# ZC3H18: (1, 512)
# HNRNPM: (1, 512)
# RPS16: (1, 512)
# ATP6V0B: (1, 512)
# SMC4: (1, 512)
# PPIL4: (1, 512)
# PSMD4: (1, 512)
# PSMC1: (1, 512)
# PPP4R2: (1, 512)
# AHCTF1: (1, 512)
# DDOST: (1, 512)
# MRGBP: (1, 512)
# RBMX: (1, 512)
# ZFC3H1: (1, 512)
# HSD17B12: (1, 512)
# TAF1D: (1, 512)
# SPC24: (1, 512)
# PKM: (1, 512)
# HMGCS1: (1, 512)
# SPCS3: (1, 512)
# SRSF7: (1, 512)
# NRBP1: (1, 512)
# FARSB: (1, 512)
# SNRNP48: (1, 512)
# ATF4: (1, 512)
# ATP6AP1: (1, 512)
# RPL14: (1, 512)
# TPR: (1, 512)
# PAM16: (1, 512)
# EP400: (1, 512)
# SEC61A1: (1, 512)
# BRD8: (1, 512)
# SPC25: (1, 512)
# PCNA: (1, 512)
# HUWE1: (1, 512)
# TELO2: (1, 512)
# RFC4: (1, 512)
# RAD21: (1, 512)
# NOLC1: (1, 512)
# PRPF3: (1, 512)
# SRP68: (1, 512)
# GSPT1: (1, 512)
# UQCRB: (1, 512)
# SDC1: (1, 512)
# HBS1L: (1, 512)
# RPL12: (1, 512)
# TWISTNB: (1, 512)
# EPRS: (1, 512)
# HNRNPU: (1, 512)
# DAD1: (1, 512)
# TIMM44: (1, 512)
# CLSPN: (1, 512)
# NOP14: (1, 512)
# XRCC5: (1, 512)
# CENPC: (1, 512)
# NOM1: (1, 512)
# DARS: (1, 512)
# OGT: (1, 512)
# DUT: (1, 512)
# AARS: (1, 512)
# PGPEP1: (1, 512)
# IARS: (1, 512)
# OPA1: (1, 512)
# SARS: (1, 512)
# CHAF1A: (1, 512)

# %%
import pandas as pd
pert_embeddings_pretrain_1d = {
    k: np.ravel(v) for k, v in pert_embeddings_pretrain.items()
}
pert_embeddings_pretrain_1d = pd.DataFrame(pert_embeddings_pretrain_1d)
pert_embeddings_pretrain_1d.to_csv("./pert_embeddings_pretrain.csv")

pert_embeddings_finetune_1d = {
    k: np.ravel(v) for k, v in pert_embeddings_finetune.items()
}
pert_embeddings_finetune_1d = pd.DataFrame(pert_embeddings_finetune_1d)
pert_embeddings_finetune_1d.to_csv("./pert_embeddings_finetune.csv")
