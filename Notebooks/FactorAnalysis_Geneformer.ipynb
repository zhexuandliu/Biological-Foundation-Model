# %% [markdown]
# # Factor Analysis - Geneformer

# %% [markdown]
# ## Loading

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/GitHub/Biological-Foundation-Model/Notebooks')

# !pip install -r ../requirements.txt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 6)) (2.8.0+cu126)
# Requirement already satisfied: transformers>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 9)) (4.55.4)
# Requirement already satisfied: peft==0.10.0 in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 11)) (0.10.0)
# Requirement already satisfied: mygene==3.2.2 in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 12)) (3.2.2)
# Requirement already satisfied: omnipath==1.0.9 in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 13)) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r ../requirements.txt (line 11)) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r ../requirements.txt (line 11)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r ../requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r ../requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r ../requirements.txt (line 11)) (1.10.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r ../requirements.txt (line 11)) (0.6.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r ../requirements.txt (line 11)) (0.34.4)
# Requirement already satisfied: biothings-client>=0.2.6 in /usr/local/lib/python3.12/dist-packages (from mygene==3.2.2->-r ../requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: attrs>=20.2.0 in /usr/local/lib/python3.12/dist-packages (from omnipath==1.0.9->-r ../requirements.txt (line 13)) (25.3.0)
# Requirement already satisfied: docrep>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from omnipath==1.0.9->-r ../requirements.txt (line 13)) (0.3.2)
# Requirement already satisfied: inflect>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from omnipath==1.0.9->-r ../requirements.txt (line 13)) (7.5.0)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.12/dist-packages (from omnipath==1.0.9->-r ../requirements.txt (line 13)) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from omnipath==1.0.9->-r ../requirements.txt (line 13)) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from omnipath==1.0.9->-r ../requirements.txt (line 13)) (2.5.0)
# Requirement already satisfied: wrapt>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from omnipath==1.0.9->-r ../requirements.txt (line 13)) (1.17.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r ../requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r ../requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r ../requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.20.0->-r ../requirements.txt (line 9)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.20.0->-r ../requirements.txt (line 9)) (0.21.4)
# Requirement already satisfied: httpx>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from biothings-client>=0.2.6->mygene==3.2.2->-r ../requirements.txt (line 12)) (0.28.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.1->omnipath==1.0.9->-r ../requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0->-r ../requirements.txt (line 11)) (1.1.8)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect>=4.1.0->omnipath==1.0.9->-r ../requirements.txt (line 13)) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect>=4.1.0->omnipath==1.0.9->-r ../requirements.txt (line 13)) (4.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->omnipath==1.0.9->-r ../requirements.txt (line 13)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->omnipath==1.0.9->-r ../requirements.txt (line 13)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->omnipath==1.0.9->-r ../requirements.txt (line 13)) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r ../requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r ../requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene==3.2.2->-r ../requirements.txt (line 12)) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene==3.2.2->-r ../requirements.txt (line 12)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene==3.2.2->-r ../requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene==3.2.2->-r ../requirements.txt (line 12)) (1.3.1)

# %%
# !cd "/content/drive/My Drive/Colab Notebooks/huggingface_models"
# !pip freeze > "/content/drive/My Drive/Colab Notebooks/huggingface_models/requirements.txt"
# %cd "/content/drive/My Drive/Colab Notebooks/huggingface_models/Geneformer"
# !pip install .

# downgrade because transformer no longer has "AdamW": https://github.com/huggingface/transformers/issues/36954
# !pip install transformers==4.40

# https://github.com/huggingface/peft/issues/2292
# !pip install peft==0.10.0

# convert gene name (like AATF as in TRRUST) to ensembl id (ENS0000... as the token for Geneformer)
# !pip install mygene

# !pip install omnipath
# Out:
# /content/drive/My Drive/Colab Notebooks/huggingface_models/Geneformer
# Processing /content/drive/My Drive/Colab Notebooks/huggingface_models/Geneformer
#   Preparing metadata (setup.py) ... done
# Collecting anndata (from geneformer==0.1.0)
#   Downloading anndata-0.12.2-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (4.0.0)
# Collecting loompy (from geneformer==0.1.0)
#   Downloading loompy-3.0.8.tar.gz (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.0.2)
# Collecting optuna (from geneformer==0.1.0)
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting optuna-integration (from geneformer==0.1.0)
#   Downloading optuna_integration-4.5.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (25.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.2.2)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.10.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (18.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2025.2)
# Collecting ray (from geneformer==0.1.0)
#   Downloading ray-2.49.1-cp312-cp312-manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting scanpy (from geneformer==0.1.0)
#   Downloading scanpy-1.11.4-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (1.16.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (75.2.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.14.5)
# Collecting tdigest (from geneformer==0.1.0)
#   Downloading tdigest-0.5.2.2-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.19.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.8.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (4.67.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (4.55.4)
# Collecting array-api-compat>=1.7.1 (from anndata->geneformer==0.1.0)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata->geneformer==0.1.0) (3.14.0)
# Collecting legacy-api-wrap (from anndata->geneformer==0.1.0)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata->geneformer==0.1.0) (8.4.0)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata->geneformer==0.1.0)
#   Downloading zarr-3.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->geneformer==0.1.0) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->geneformer==0.1.0) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (3.19.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (6.0.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from loompy->geneformer==0.1.0) (0.60.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from loompy->geneformer==0.1.0) (8.2.1)
# Collecting numpy-groupies (from loompy->geneformer==0.1.0)
#   Downloading numpy_groupies-0.11.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (3.2.3)
# Collecting alembic>=1.5.0 (from optuna->geneformer==0.1.0)
#   Downloading alembic-1.16.5-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna->geneformer==0.1.0)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->geneformer==0.1.0) (2.0.43)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft->geneformer==0.1.0) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft->geneformer==0.1.0) (1.10.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft->geneformer==0.1.0) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.4.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray->geneformer==0.1.0) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray->geneformer==0.1.0) (1.1.1)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from ray->geneformer==0.1.0) (5.29.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (1.5.1)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (0.5.13)
# Collecting session-info2 (from scanpy->geneformer==0.1.0)
#   Downloading session_info2-0.2.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (0.5.9.post2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->geneformer==0.1.0) (3.6.0)
# Collecting accumulation-tree (from tdigest->geneformer==0.1.0)
#   Downloading accumulation_tree-0.6.4.tar.gz (12 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyudorandom (from tdigest->geneformer==0.1.0)
#   Downloading pyudorandom-1.0.0.tar.gz (1.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (3.8.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->geneformer==0.1.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers->geneformer==0.1.0) (0.21.4)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->geneformer==0.1.0) (1.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (3.12.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets->geneformer==0.1.0) (1.1.8)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->loompy->geneformer==0.1.0) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->geneformer==0.1.0) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->geneformer==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->geneformer==0.1.0) (3.0.2)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata->geneformer==0.1.0)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata->geneformer==0.1.0)
#   Downloading numcodecs-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (0.27.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (1.20.1)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata->geneformer==0.1.0)
#   Downloading crc32c-2.7.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Downloading anndata-0.12.2-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 kB 8.6 MB/s eta 0:00:00
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 16.3 MB/s eta 0:00:00
# Downloading optuna_integration-4.5.0-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.7 MB/s eta 0:00:00
# Downloading ray-2.49.1-cp312-cp312-manylinux2014_x86_64.whl (70.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 MB 9.2 MB/s eta 0:00:00
# Downloading scanpy-1.11.4-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.6 MB/s eta 0:00:00
# Downloading tdigest-0.5.2.2-py3-none-any.whl (9.4 kB)
# Downloading alembic-1.16.5-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.4/247.4 kB 17.1 MB/s eta 0:00:00
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 3.5 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading zarr-3.1.2-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 17.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading numpy_groupies-0.11.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.5 MB/s eta 0:00:00
# Downloading session_info2-0.2.1-py3-none-any.whl (16 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 105.5 MB/s eta 0:00:00
# Downloading crc32c-2.7.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 3.3 MB/s eta 0:00:00
# Building wheels for collected packages: geneformer, loompy, accumulation-tree, pyudorandom
#   Building wheel for geneformer (setup.py) ... done
#   Created wheel for geneformer: filename=geneformer-0.1.0-py3-none-any.whl size=2410396 sha256=745e4d10014324f883d665dd3122abdab4dbb44eb700f4d48ce91807cc3fca82
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sth4irsv/wheels/11/0c/61/3c7cc3be8408c2e8e59120ac283f66cb87fec65d8e501d2ed3
#   Building wheel for loompy (setup.py) ... done
#   Created wheel for loompy: filename=loompy-3.0.8-py3-none-any.whl size=54012 sha256=b6879e6f9278093046bec2eb2f467aaedd2180c1410365a9f7fa49c0d8baa0d6
#   Stored in directory: /root/.cache/pip/wheels/2e/45/28/2c7afc7f9eab47612e1b5090cfb9ba0f00777625064039a6af
#   Building wheel for accumulation-tree (pyproject.toml) ... done
#   Created wheel for accumulation-tree: filename=accumulation_tree-0.6.4-cp312-cp312-linux_x86_64.whl size=407378 sha256=eb6c89fd128850f380ccbe6332988d98816b054a652827308ac202f84258027b
#   Stored in directory: /root/.cache/pip/wheels/ab/17/fc/25ff5fbcee96932da7648047b237d92a9977c12ff46fb4211c
#   Building wheel for pyudorandom (setup.py) ... done
#   Created wheel for pyudorandom: filename=pyudorandom-1.0.0-py3-none-any.whl size=2191 sha256=bd680b9c25b495862531f53f0a62c5ebf6a58aab262f0b7af04f4d336266d489
#   Stored in directory: /root/.cache/pip/wheels/1c/2c/be/2cfa942ed278bec31ef15f191c17cb33501d3bc1b40524c1d0
# Successfully built geneformer loompy accumulation-tree pyudorandom
# Installing collected packages: pyudorandom, accumulation-tree, tdigest, session-info2, numpy-groupies, numcodecs, legacy-api-wrap, donfig, crc32c, colorlog, array-api-compat, loompy, alembic, zarr, optuna, ray, optuna-integration, anndata, scanpy, geneformer
# Successfully installed accumulation-tree-0.6.4 alembic-1.16.5 anndata-0.12.2 array-api-compat-1.12.0 colorlog-6.9.0 crc32c-2.7.1 donfig-0.8.1.post1 geneformer-0.1.0 legacy-api-wrap-1.4.1 loompy-3.0.8 numcodecs-0.16.2 numpy-groupies-0.11.3 optuna-4.5.0 optuna-integration-4.5.0 pyudorandom-1.0.0 ray-2.49.1 scanpy-1.11.4 session-info2-0.2.1 tdigest-0.5.2.2 zarr-3.1.2
# Collecting transformers==4.40
#   Downloading transformers-4.40.0-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (2.32.4)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.40)
#   Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.40) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40) (1.1.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.40) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.40) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.40) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.40) (2025.8.3)
# Downloading transformers-4.40.0-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 38.5 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 43.5 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.4
#     Uninstalling tokenizers-0.21.4:
#       Successfully uninstalled tokenizers-0.21.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.55.4
#     Uninstalling transformers-4.55.4:
#       Successfully uninstalled transformers-4.55.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.0 which is incompatible.
# Successfully installed tokenizers-0.19.1 transformers-4.40.0
# Requirement already satisfied: peft==0.10.0 in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (2.8.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (4.40.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (1.10.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (0.6.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0) (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (1.1.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.10.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.10.0) (0.19.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft==0.10.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft==0.10.0) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (2025.8.3)
# Requirement already satisfied: mygene in /usr/local/lib/python3.12/dist-packages (3.2.2)
# Requirement already satisfied: biothings-client>=0.2.6 in /usr/local/lib/python3.12/dist-packages (from mygene) (0.4.1)
# Requirement already satisfied: httpx>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from biothings-client>=0.2.6->mygene) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (4.10.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene) (4.15.0)
# Requirement already satisfied: omnipath in /usr/local/lib/python3.12/dist-packages (1.0.9)
# Requirement already satisfied: attrs>=20.2.0 in /usr/local/lib/python3.12/dist-packages (from omnipath) (25.3.0)
# Requirement already satisfied: docrep>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from omnipath) (0.3.2)
# Requirement already satisfied: inflect>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from omnipath) (7.5.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from omnipath) (25.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from omnipath) (2.2.2)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.12/dist-packages (from omnipath) (2.32.4)
# Requirement already satisfied: tqdm>=4.51.0 in /usr/local/lib/python3.12/dist-packages (from omnipath) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from omnipath) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from omnipath) (2.5.0)
# Requirement already satisfied: wrapt>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from omnipath) (1.17.3)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.1->omnipath) (1.17.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect>=4.1.0->omnipath) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect>=4.1.0->omnipath) (4.4.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->omnipath) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->omnipath) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->omnipath) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->omnipath) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->omnipath) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->omnipath) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->omnipath) (2025.8.3)

# %%
## prepare data
from datasets import load_dataset, load_from_disk
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import numpy as np
import pandas as pd

from geneformer import TOKEN_DICTIONARY_FILE
from geneformer import perturber_utils as pu
from geneformer import TranscriptomeTokenizer

# load the training data and the tokenizer from Geneformer
dataset = load_from_disk("/content/drive/My Drive/Colab Notebooks/datasets/geneformer/cell_type_train_data.dataset") # 249556 data points
with open("/content/drive/My Drive/Colab Notebooks/huggingface_models/Geneformer/geneformer/gene_dictionaries_30m/token_dictionary_gc30M.pkl", "rb") as f:
    token_dict = pickle.load(f)


# load model
model = pu.load_model("Pretrained", num_classes = 0, model_directory = "/content/drive/My Drive/Colab Notebooks/huggingface_models/Geneformer/gf-12L-30M-i2048", mode="eval")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2110339669.py in <cell line: 0>()
#       8 import pandas as pd
#       9
# ---> 10 from geneformer import TOKEN_DICTIONARY_FILE
#      11 from geneformer import perturber_utils as pu
#      12 from geneformer import TranscriptomeTokenizer
#
# ModuleNotFoundError: No module named 'geneformer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Factor Analysis

# %%
with open("/content/drive/MyDrive/Colab Notebooks/Structural_Probe_Gene/data/30M_6L_features/H_list_l6_STRING_10000.pkl", "rb") as f:
    H_list = pickle.load(f)

import random
random.seed(0)
cell_indices = random.sample(list(range(len(dataset))), 10000)
input_ids_list = [dataset[idx]["input_ids"] for idx in cell_indices]

# %%
# create the averaged feature matrix.

vocab_size = len(token_dict)
feature_dim = 256

count_vector = np.zeros(vocab_size)
sum_matrix = np.zeros((vocab_size, feature_dim))

for H, input_ids in zip(H_list, input_ids_list):
    for j in range(len(input_ids)):
        token_id = input_ids[j]
        sum_matrix[token_id] += H[j]
        count_vector[token_id] += 1

# Compute averages (avoid divide by zero)
avg_matrix = np.zeros_like(sum_matrix)
nonzero_indices = count_vector > 0
avg_matrix[nonzero_indices] = sum_matrix[nonzero_indices] / count_vector[nonzero_indices, np.newaxis]

# %% [markdown]
# # Factor analysis

# %%
from sklearn.decomposition import FactorAnalysis

n_factors = 10
fa = FactorAnalysis(n_components=n_factors, random_state=0)
X_fa = fa.fit_transform(avg_matrix)

# %%
avg_matrix.shape
# Out:
# (25426, 256)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming X_fa is the (n_tokens × n_factors) matrix from factor analysis
n_factors = X_fa.shape[1]
n_tokens = X_fa.shape[0]

# Plot each factor's values across tokens
for i in range(n_factors):
    plt.figure(figsize=(8, 3))
    plt.hist(X_fa[:, i])
    plt.xlabel("Token index")
    plt.ylabel("Factor score")
    plt.title(f"Factor {i + 1}")
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a77bf9bf679> in <cell line: 0>()
#       3
#       4 # Assuming X_fa is the (n_tokens × n_factors) matrix from factor analysis
# ----> 5 n_factors = X_fa.shape[1]
#       6 n_tokens = X_fa.shape[0]
#       7
#
# NameError: name 'X_fa' is not defined
